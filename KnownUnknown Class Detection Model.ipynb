# %%
import os
import csv

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import xgboost as xgb
from sklearn.externals import joblib
from sklearn.utils import compute_class_weight
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.metrics import classification_report, f1_score, roc_auc_score, accuracy_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, LabelBinarizer, StandardScaler, LabelEncoder
from sklearn.linear_model.logistic import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from keras import Sequential
from keras import optimizers
from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.layers import Dropout, Dense
from keras.models import load_model
# Out:
# C:\Users\lim_j\AppData\Local\conda\conda\envs\py36\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %% [markdown]
# Load cleaned data from pickle file

# %%
cleaned_df = joblib.load('pickles/cleaned_df.pkl')

# %% [markdown]
# Load top 50 features and extract top 50 features into a list

# %%
trimmed_feats_list = joblib.load('pickles/57var.pkl')
trimmed_feats_list.append('device_category')

# %% [markdown]
# Filter dataset to only use the 57 relevant features

# %%
filtered_df = cleaned_df.filter(items=trimmed_feats_list, axis='columns')

# %%
filtered_df.shape
# Out:
# (399348, 57)

# %% [markdown]
# Obtain list of unique classes and create list of names of feature engineered columns

# %%
distinct_classes = filtered_df.device_category.unique()
training_cols = ['sd', 'sem', 'var', 'skew', 'kurt', 'mad', 'shortest_dist_sd', 'shortest_dist_diff', 'sd_diff_smallest2next', 'known']

# %% [markdown]
# Build training dataset for known/unknown detection classifier

# %%
training_df = pd.DataFrame()
knn = KNeighborsClassifier(n_neighbors=9, weights='uniform', algorithm='auto', p=2, n_jobs=-1, leaf_size=30)

for out_class in distinct_classes:
    nine_classes_list = distinct_classes.tolist()
    nine_classes_list.remove(out_class)
    
    in_classes_samples = pd.DataFrame()
    nine_classes_df = filtered_df[filtered_df['device_category'] != out_class]
    out_class_df = filtered_df[filtered_df['device_category'] == out_class]
    
    for in_class in nine_classes_list:
        in_class_df = filtered_df[filtered_df['device_category'] == in_class]
        in_class_sample = in_class_df.sample(500, random_state=1, axis=0, replace=True)
        index_to_drop = in_class_sample.index.tolist()
        nine_classes_df = nine_classes_df.drop(index_to_drop)
        in_class_sample = in_class_sample.reset_index()
        in_classes_samples = pd.concat([in_classes_samples, in_class_sample], axis=0, ignore_index=True)
    
    train_x, _, train_y, _ = train_test_split(nine_classes_df.iloc[:, :-1], nine_classes_df.iloc[:, -1], train_size=900, 
                                              test_size=9, random_state=1, shuffle=True, stratify=nine_classes_df.iloc[:, -1])
    knn.fit(train_x, train_y)
    
    val_x, val_y = in_classes_samples.iloc[:, 1:-1], in_classes_samples.iloc[:, -1]
    val_output = knn.kneighbors(val_x, n_neighbors=9, return_distance=True)
    val_distance_df = pd.DataFrame([[distance for distance in row] for row in val_output[0]])
    val_sd = val_distance_df.std(axis=1, numeric_only=True)
    val_min = val_distance_df.min(axis=1, numeric_only=True)
    val_mean = val_distance_df.mean(axis=1, numeric_only=True)
    val_2_smallest_dist_df = pd.DataFrame(np.sort(val_distance_df.values))
    val_2nd_smallest_dist_df = val_2_smallest_dist_df.iloc[:, -2]
    val_smallest_dist_df = val_2_smallest_dist_df.iloc[:, -1]
    
    val_distance_df['sd'] = val_sd
    val_distance_df['sem'] = val_distance_df.sem(axis=1, numeric_only=True)
    val_distance_df['var'] = val_distance_df.var(axis=1, numeric_only=True)
    val_distance_df['skew'] = val_distance_df.skew(axis=1, numeric_only=True)
    val_distance_df['kurt'] = val_distance_df.kurt(axis=1, numeric_only=True)
    val_distance_df['mad'] = val_distance_df.mad(axis=1)
    val_distance_df['shortest_dist_sd'] = val_smallest_dist_df / val_sd
    val_distance_df['shortest_dist_diff'] = (val_mean - val_min) / val_sd
    val_distance_df['sd_diff_smallest2next'] = (val_2nd_smallest_dist_df - val_min) / val_sd 
    val_distance_df['known'] = pd.Series([1 for _ in range(len(val_distance_df.index))]) 
    
    
    out_class_df = out_class_df.sample(n=4500, random_state=1, axis=0, replace=True)
    test_x, test_y = out_class_df.iloc[:, :-1], out_class_df.iloc[:, -1]
    test_output = knn.kneighbors(test_x, n_neighbors=9, return_distance=True)
    
    test_distance_df = pd.DataFrame([[distance for distance in row] for row in test_output[0]])
    test_sd = test_distance_df.std(axis=1, numeric_only=True)
    test_min = test_distance_df.min(axis=1, numeric_only=True)
    test_mean = test_distance_df.mean(axis=1, numeric_only=True)
    test_2_smallest_dist_df = pd.DataFrame(np.sort(test_distance_df.values))
    test_2nd_smallest_dist_df = test_2_smallest_dist_df.iloc[:, -2]
    test_smallest_dist_df = test_2_smallest_dist_df.iloc[:, -1]

    
    test_distance_df['sd'] = test_sd
    test_distance_df['sem'] = test_distance_df.sem(axis=1, numeric_only=True)
    test_distance_df['var'] = test_distance_df.var(axis=1, numeric_only=True)
    test_distance_df['skew'] = test_distance_df.skew(axis=1, numeric_only=True)
    test_distance_df['kurt'] = test_distance_df.kurt(axis=1, numeric_only=True)
    test_distance_df['mad'] = test_distance_df.mad(axis=1)
    test_distance_df['shortest_dist_sd'] = test_smallest_dist_df / test_sd
    test_distance_df['shortest_dist_diff'] = (test_mean - test_min) / test_sd
    test_distance_df['sd_diff_smallest2next'] = (test_2nd_smallest_dist_df - test_min) / test_sd 
    test_distance_df['known'] = pd.Series([0 for _ in range(len(test_distance_df.index))]) 
    
    
    combined_df = pd.concat([val_distance_df, test_distance_df], axis=0, ignore_index=True).filter(items=training_cols, axis='columns')
    training_df = pd.concat([training_df, combined_df], axis=0, ignore_index=True)

# %% [markdown]
# Check counts of labels

# %%
training_df['known'].value_counts()
# Out:
# 1    45000
# 0    45000
# Name: known, dtype: int64

# %% [markdown]
# Clean up the dataset

# %%
training_df = training_df.replace([np.inf, -np.inf], np.nan)
training_df = training_df.replace(np.nan, 0)

# %% [markdown]
# Save the labelled dataset obtained from KNN models

# %%
joblib.dump(training_df, 'pickles/known_classifier_dataset_v4.pkl', compress=9)
# Out:
# ['pickles/known_classifier_dataset_v4.pkl']

# %% [markdown]
# Load the labelled dataset obtained from KNN models

# %%
training_df = joblib.load('pickles/known_classifier_dataset_v4.pkl')

# %%
training_df.head()
# Out:
#           sd        sem          var      skew       kurt         mad  \
# 0   0.000014   0.028573     0.012098 -1.336372  10.752406    1.413319
# 1   0.004105   0.001420     0.000026 -0.359471  12.909395    1.715045
# 2   0.002004   0.000802     0.000009 -0.434234  12.976511    1.725100
# 3   0.062109   0.018761     0.003192  2.760041  12.842279    1.902902
# 4  70.996114  22.394521  5703.710788  3.451707  12.918827  742.258942
#
#    shortest_dist_sd  shortest_dist_diff  sd_diff_smallest2next  known
# 0      19755.275816            0.974932               2.185684      1
# 1          3.768646            1.942897               2.882156      1
# 2          5.493141            1.278810               1.885052      1
# 3          3.101878            0.501448               0.733738      1
# 4          3.667352            0.966265               1.835213      1

# %% [markdown]
# ### Prepare feature engineered dataset, splitting to train-test using 80-20 ratio
# Scale using standard scaling so that models are able to better learn from dataset

# %%
x, y = training_df.drop('known', axis=1), training_df['known']
class_weights = compute_class_weight('balanced', np.unique(y), y)
scaler = StandardScaler()
x = scaler.fit_transform(x)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=1)

# %% [markdown]
# ### Logistic Regression Model for KnownUnknown Class Detection
# #### Using Stochastic Average Gradient for negate the large dataset impact on training time

# %%
log_reg = LogisticRegression(penalty='l2', dual=False, class_weight='balanced', random_state=5, max_iter=500, 
                             multi_class='ovr', verbose=2, n_jobs=-1, solver='sag')
log_reg.fit(x_train, y_train)
# Out:
# convergence after 30 epochs took 1 seconds
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    3.0s finished
# LogisticRegression(C=1.0, class_weight='balanced', dual=False,
#           fit_intercept=True, intercept_scaling=1, max_iter=500,
#           multi_class='ovr', n_jobs=-1, penalty='l2', random_state=5,
#           solver='sag', tol=0.0001, verbose=2, warm_start=False)

# %% [markdown]
# Logistic Regression Model Predictions

# %%
log_reg_preds = log_reg.predict(x_test)

# %% [markdown]
# Classification Report to validate model performance

# %%
print(classification_report(y_test, log_reg_preds))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.58      0.68      0.62      8980
#           1       0.61      0.51      0.56      9020
#
# avg / total       0.60      0.59      0.59     18000

# %% [markdown]
# ### Random Forest Model for KnownUnknown Class Detection
# #### Using 1000 Decision Trees, Bagging and balancing class weights

# %%
rf = RandomForestClassifier(1000, criterion='gini', oob_score=True, n_jobs=-1,
                            random_state=5, class_weight='balanced', verbose=1)
rf.fit(x_train, y_train)
# Out:
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:    3.6s
# [Parallel(n_jobs=-1)]: Done 192 tasks      | elapsed:   16.6s
# [Parallel(n_jobs=-1)]: Done 442 tasks      | elapsed:   36.3s
# [Parallel(n_jobs=-1)]: Done 792 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 1000 out of 1000 | elapsed:  1.3min finished
# RandomForestClassifier(bootstrap=True, class_weight='balanced',
#             criterion='gini', max_depth=None, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=1000, n_jobs=-1, oob_score=True, random_state=5,
#             verbose=1, warm_start=False)

# %% [markdown]
# Random Forest Model Predictions

# %%
rf_preds = rf.predict(x_test)
# Out:
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done 192 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=4)]: Done 442 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=4)]: Done 792 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=4)]: Done 1000 out of 1000 | elapsed:    3.6s finished

# %%
print(classification_report(y_test, rf_preds))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.92      0.87      0.89      8980
#           1       0.87      0.92      0.90      9020
#
# avg / total       0.90      0.90      0.90     18000

# %% [markdown]
# ### XGBoost Model for KnownUnknown Class Detection

# %%
dtrain = xgb.DMatrix(x_train, label=np.array(y_train))
dtest = xgb.DMatrix(x_test, label=np.array(y_test))

# %%
x_train.shape
# Out:
# (72000, 9)

# %%
param = {
    'max_depth': 10,
    'eta': 0.1,
    'silent': 0,
    'objective': 'binary:logistic',
    'eval_metric': 'error'
}
num_round = 1000

# %%
bst = xgb.train(param, dtrain, num_round, evals=[(dtest,'eval'), (dtrain,'train')])
# Out:
# [0]	eval-error:0.243778	train-error:0.240611
# [1]	eval-error:0.240833	train-error:0.235528
# [2]	eval-error:0.242167	train-error:0.236486
# [3]	eval-error:0.242444	train-error:0.234361
# [4]	eval-error:0.242722	train-error:0.234861
# [5]	eval-error:0.244667	train-error:0.239167
# [6]	eval-error:0.244278	train-error:0.238736
# [7]	eval-error:0.244	train-error:0.238125
# [8]	eval-error:0.239722	train-error:0.233222
# [9]	eval-error:0.240222	train-error:0.234194
# [10]	eval-error:0.239389	train-error:0.233181
# [11]	eval-error:0.239778	train-error:0.233319
# [12]	eval-error:0.239944	train-error:0.233278
# [13]	eval-error:0.240611	train-error:0.233458
# [14]	eval-error:0.240167	train-error:0.232972
# [15]	eval-error:0.231	train-error:0.220639
# [16]	eval-error:0.2325	train-error:0.221653
# [17]	eval-error:0.232556	train-error:0.222236
# [18]	eval-error:0.232944	train-error:0.221903
# [19]	eval-error:0.224333	train-error:0.213069
# [20]	eval-error:0.224111	train-error:0.212778
# [21]	eval-error:0.223056	train-error:0.211944
# [22]	eval-error:0.223222	train-error:0.212028
# [23]	eval-error:0.222833	train-error:0.212139
# [24]	eval-error:0.223167	train-error:0.211653
# [25]	eval-error:0.223056	train-error:0.211375
# [26]	eval-error:0.222722	train-error:0.210792
# [27]	eval-error:0.222667	train-error:0.210653
# [28]	eval-error:0.223833	train-error:0.211431
# [29]	eval-error:0.224222	train-error:0.2115
# [30]	eval-error:0.224722	train-error:0.211542
# [31]	eval-error:0.220722	train-error:0.207403
# [32]	eval-error:0.220778	train-error:0.207042
# [33]	eval-error:0.220722	train-error:0.207028
# [34]	eval-error:0.220722	train-error:0.206944
# [35]	eval-error:0.220556	train-error:0.206681
# [36]	eval-error:0.2205	train-error:0.206722
# [37]	eval-error:0.220611	train-error:0.206722
# [38]	eval-error:0.220278	train-error:0.206347
# [39]	eval-error:0.220444	train-error:0.206056
# [40]	eval-error:0.220333	train-error:0.205931
# [41]	eval-error:0.220222	train-error:0.206056
# [42]	eval-error:0.220167	train-error:0.205778
# [43]	eval-error:0.220333	train-error:0.205764
# [44]	eval-error:0.220556	train-error:0.205681
# [45]	eval-error:0.221278	train-error:0.20625
# [46]	eval-error:0.221222	train-error:0.206097
# [47]	eval-error:0.220167	train-error:0.204986
# [48]	eval-error:0.220167	train-error:0.20475
# [49]	eval-error:0.220167	train-error:0.203042
# [50]	eval-error:0.220056	train-error:0.202778
# [51]	eval-error:0.22	train-error:0.202569
# [52]	eval-error:0.219833	train-error:0.202528
# [53]	eval-error:0.219667	train-error:0.201569
# [54]	eval-error:0.219778	train-error:0.201556
# [55]	eval-error:0.219389	train-error:0.201486
# [56]	eval-error:0.219444	train-error:0.201472
# [57]	eval-error:0.219444	train-error:0.201431
# [58]	eval-error:0.219	train-error:0.201153
# [59]	eval-error:0.218722	train-error:0.200764
# [60]	eval-error:0.218667	train-error:0.200694
# [61]	eval-error:0.219056	train-error:0.200681
# [62]	eval-error:0.217889	train-error:0.199431
# [63]	eval-error:0.217833	train-error:0.199264
# [64]	eval-error:0.217833	train-error:0.199264
# [65]	eval-error:0.217778	train-error:0.199125
# [66]	eval-error:0.217333	train-error:0.198486
# [67]	eval-error:0.216611	train-error:0.197833
# [68]	eval-error:0.216444	train-error:0.197722
# [69]	eval-error:0.216222	train-error:0.197028
# [70]	eval-error:0.215722	train-error:0.196403
# [71]	eval-error:0.215778	train-error:0.196375
# [72]	eval-error:0.215444	train-error:0.195042
# [73]	eval-error:0.214667	train-error:0.193833
# [74]	eval-error:0.214778	train-error:0.193764
# [75]	eval-error:0.214778	train-error:0.193639
# [76]	eval-error:0.2145	train-error:0.193389
# [77]	eval-error:0.214556	train-error:0.193222
# [78]	eval-error:0.214556	train-error:0.193264
# [79]	eval-error:0.2145	train-error:0.193208
# [80]	eval-error:0.214056	train-error:0.192639
# [81]	eval-error:0.213889	train-error:0.191931
# [82]	eval-error:0.213778	train-error:0.191542
# [83]	eval-error:0.213556	train-error:0.191306
# [84]	eval-error:0.213278	train-error:0.190806
# [85]	eval-error:0.213222	train-error:0.190611
# [86]	eval-error:0.213111	train-error:0.190514
# [87]	eval-error:0.213167	train-error:0.190458
# [88]	eval-error:0.213111	train-error:0.190236
# [89]	eval-error:0.212778	train-error:0.190028
# [90]	eval-error:0.212778	train-error:0.190028
# [91]	eval-error:0.212667	train-error:0.189806
# [92]	eval-error:0.212667	train-error:0.189806
# [93]	eval-error:0.212556	train-error:0.189125
# [94]	eval-error:0.211444	train-error:0.187611
# [95]	eval-error:0.211444	train-error:0.187583
# [96]	eval-error:0.211444	train-error:0.187278
# [97]	eval-error:0.211389	train-error:0.186861
# [98]	eval-error:0.2115	train-error:0.186625
# [99]	eval-error:0.211	train-error:0.186069
# [100]	eval-error:0.211	train-error:0.186069
# [101]	eval-error:0.210944	train-error:0.185944
# [102]	eval-error:0.211	train-error:0.185917
# [103]	eval-error:0.210889	train-error:0.185444
# [104]	eval-error:0.210833	train-error:0.185028
# [105]	eval-error:0.210722	train-error:0.184764
# [106]	eval-error:0.210611	train-error:0.184417
# [107]	eval-error:0.210667	train-error:0.184361
# [108]	eval-error:0.210667	train-error:0.184361
# [109]	eval-error:0.210167	train-error:0.183514
# [110]	eval-error:0.209889	train-error:0.183278
# [111]	eval-error:0.209722	train-error:0.183194
# [112]	eval-error:0.209722	train-error:0.183139
# [113]	eval-error:0.209722	train-error:0.182986
# [114]	eval-error:0.209722	train-error:0.182986
# [115]	eval-error:0.209889	train-error:0.182944
# [116]	eval-error:0.209833	train-error:0.182611
# [117]	eval-error:0.209333	train-error:0.182181
# [118]	eval-error:0.209278	train-error:0.181875
# [119]	eval-error:0.2095	train-error:0.181819
# [120]	eval-error:0.209167	train-error:0.181625
# [121]	eval-error:0.208944	train-error:0.181625
# [122]	eval-error:0.208889	train-error:0.181556
# [123]	eval-error:0.208556	train-error:0.181292
# [124]	eval-error:0.208444	train-error:0.181083
# [125]	eval-error:0.2085	train-error:0.181153
# [126]	eval-error:0.208722	train-error:0.181083
# [127]	eval-error:0.208611	train-error:0.181125
# [128]	eval-error:0.208722	train-error:0.181083
# [129]	eval-error:0.208444	train-error:0.180819
# [130]	eval-error:0.208444	train-error:0.180806
# [131]	eval-error:0.208611	train-error:0.180611
# [132]	eval-error:0.208667	train-error:0.180431
# [133]	eval-error:0.208611	train-error:0.180403
# [134]	eval-error:0.2085	train-error:0.180194
# [135]	eval-error:0.2085	train-error:0.180181
# [136]	eval-error:0.208333	train-error:0.180042
# [137]	eval-error:0.207556	train-error:0.179347
# [138]	eval-error:0.207611	train-error:0.179028
# [139]	eval-error:0.207167	train-error:0.178625
# [140]	eval-error:0.207	train-error:0.178444
# [141]	eval-error:0.207222	train-error:0.178194
# [142]	eval-error:0.207222	train-error:0.178167
# [143]	eval-error:0.207111	train-error:0.177764
# [144]	eval-error:0.207167	train-error:0.17775
# [145]	eval-error:0.207111	train-error:0.177542
# [146]	eval-error:0.206889	train-error:0.177431
# [147]	eval-error:0.206944	train-error:0.177361
# [148]	eval-error:0.207056	train-error:0.177
# [149]	eval-error:0.207111	train-error:0.176806
# [150]	eval-error:0.207167	train-error:0.176694
# [151]	eval-error:0.207278	train-error:0.176625
# [152]	eval-error:0.207222	train-error:0.176528
# [153]	eval-error:0.207389	train-error:0.176389
# [154]	eval-error:0.207389	train-error:0.176361
# [155]	eval-error:0.2075	train-error:0.176389
# [156]	eval-error:0.2075	train-error:0.176389
# [157]	eval-error:0.207111	train-error:0.176111
# [158]	eval-error:0.206944	train-error:0.176028
# [159]	eval-error:0.207056	train-error:0.176014
# [160]	eval-error:0.206833	train-error:0.175958
# [161]	eval-error:0.206667	train-error:0.175903
# [162]	eval-error:0.207	train-error:0.175986
# [163]	eval-error:0.206778	train-error:0.175597
# [164]	eval-error:0.206889	train-error:0.175556
# [165]	eval-error:0.206667	train-error:0.175361
# [166]	eval-error:0.206667	train-error:0.175361
# [167]	eval-error:0.206667	train-error:0.175333
# [168]	eval-error:0.206722	train-error:0.175333
# [169]	eval-error:0.206833	train-error:0.175347
# [170]	eval-error:0.206778	train-error:0.175347
# [171]	eval-error:0.206944	train-error:0.175181
# [172]	eval-error:0.206944	train-error:0.175181
# [173]	eval-error:0.206944	train-error:0.175167
# [174]	eval-error:0.207	train-error:0.175167
# [175]	eval-error:0.206944	train-error:0.175125
# [176]	eval-error:0.206944	train-error:0.175111
# [177]	eval-error:0.207167	train-error:0.174875
# [178]	eval-error:0.207167	train-error:0.17475
# [179]	eval-error:0.206833	train-error:0.174667
# [180]	eval-error:0.206722	train-error:0.174375
# [181]	eval-error:0.206778	train-error:0.174236
# [182]	eval-error:0.206722	train-error:0.174194
# [183]	eval-error:0.206556	train-error:0.174153
# [184]	eval-error:0.206556	train-error:0.174069
# [185]	eval-error:0.206611	train-error:0.173986
# [186]	eval-error:0.206556	train-error:0.173903
# [187]	eval-error:0.206444	train-error:0.173903
# [188]	eval-error:0.206444	train-error:0.173764
# [189]	eval-error:0.206444	train-error:0.173764
# [190]	eval-error:0.206444	train-error:0.173625
# [191]	eval-error:0.206611	train-error:0.173278
# [192]	eval-error:0.2065	train-error:0.173
# [193]	eval-error:0.2065	train-error:0.173
# [194]	eval-error:0.2065	train-error:0.172972
# [195]	eval-error:0.2065	train-error:0.172958
# [196]	eval-error:0.2065	train-error:0.172931
# [197]	eval-error:0.2065	train-error:0.172917
# [198]	eval-error:0.206444	train-error:0.172903
# [199]	eval-error:0.2065	train-error:0.172903
# [200]	eval-error:0.206389	train-error:0.172708
# [201]	eval-error:0.206278	train-error:0.172444
# [202]	eval-error:0.206222	train-error:0.172417
# [203]	eval-error:0.206333	train-error:0.172306
# [204]	eval-error:0.205833	train-error:0.172181
# [205]	eval-error:0.205889	train-error:0.172083
# [206]	eval-error:0.205778	train-error:0.172014
# [207]	eval-error:0.205722	train-error:0.171833
# [208]	eval-error:0.2055	train-error:0.171653
# [209]	eval-error:0.205167	train-error:0.171444
# [210]	eval-error:0.205167	train-error:0.171403
# [211]	eval-error:0.205111	train-error:0.171375
# [212]	eval-error:0.205278	train-error:0.171208
# [213]	eval-error:0.205389	train-error:0.171042
# [214]	eval-error:0.2055	train-error:0.170958
# [215]	eval-error:0.2055	train-error:0.170889
# [216]	eval-error:0.205389	train-error:0.170861
# [217]	eval-error:0.205556	train-error:0.170528
# [218]	eval-error:0.205611	train-error:0.170556
# [219]	eval-error:0.205611	train-error:0.170542
# [220]	eval-error:0.205722	train-error:0.1705
# [221]	eval-error:0.205667	train-error:0.170472
# [222]	eval-error:0.205611	train-error:0.170472
# [223]	eval-error:0.205556	train-error:0.170458
# [224]	eval-error:0.205444	train-error:0.170431
# [225]	eval-error:0.205389	train-error:0.170444
# [226]	eval-error:0.2055	train-error:0.170361
# [227]	eval-error:0.2055	train-error:0.170347
# [228]	eval-error:0.205611	train-error:0.170264
# [229]	eval-error:0.2055	train-error:0.170236
# [230]	eval-error:0.2055	train-error:0.170236
# [231]	eval-error:0.205389	train-error:0.170125
# [232]	eval-error:0.205333	train-error:0.16975
# [233]	eval-error:0.205556	train-error:0.169528
# [234]	eval-error:0.205556	train-error:0.169514
# [235]	eval-error:0.2055	train-error:0.169486
# [236]	eval-error:0.2055	train-error:0.169486
# [237]	eval-error:0.205556	train-error:0.169486
# [238]	eval-error:0.2055	train-error:0.169236
# [239]	eval-error:0.205278	train-error:0.169208
# [240]	eval-error:0.205278	train-error:0.169125
# [241]	eval-error:0.205278	train-error:0.169097
# [242]	eval-error:0.205278	train-error:0.169056
# [243]	eval-error:0.205278	train-error:0.169056
# [244]	eval-error:0.205111	train-error:0.169014
# [245]	eval-error:0.205	train-error:0.169028
# [246]	eval-error:0.205	train-error:0.169028
# [247]	eval-error:0.205	train-error:0.169028
# [248]	eval-error:0.205056	train-error:0.169014
# [249]	eval-error:0.205056	train-error:0.168986
# [250]	eval-error:0.205056	train-error:0.168986
# [251]	eval-error:0.205167	train-error:0.168944
# [252]	eval-error:0.205167	train-error:0.168958
# [253]	eval-error:0.205167	train-error:0.168958
# [254]	eval-error:0.205167	train-error:0.168958
# [255]	eval-error:0.205	train-error:0.168889
# [256]	eval-error:0.205	train-error:0.168875
# [257]	eval-error:0.204944	train-error:0.168875
# [258]	eval-error:0.205056	train-error:0.168875
# [259]	eval-error:0.205056	train-error:0.168875
# [260]	eval-error:0.205111	train-error:0.168875
# [261]	eval-error:0.205056	train-error:0.168861
# [262]	eval-error:0.205111	train-error:0.168833
# [263]	eval-error:0.205	train-error:0.168792
# [264]	eval-error:0.204944	train-error:0.168694
# [265]	eval-error:0.205	train-error:0.168681
# [266]	eval-error:0.204944	train-error:0.168681
# [267]	eval-error:0.204889	train-error:0.168625
# [268]	eval-error:0.204778	train-error:0.168625
# [269]	eval-error:0.204833	train-error:0.168528
# [270]	eval-error:0.204833	train-error:0.168528
# [271]	eval-error:0.204889	train-error:0.168375
# [272]	eval-error:0.205	train-error:0.16825
# [273]	eval-error:0.205111	train-error:0.16825
# [274]	eval-error:0.205167	train-error:0.168222
# [275]	eval-error:0.205056	train-error:0.168056
# [276]	eval-error:0.205	train-error:0.168069
# [277]	eval-error:0.204778	train-error:0.167958
# [278]	eval-error:0.204778	train-error:0.167972
# [279]	eval-error:0.204611	train-error:0.167819
# [280]	eval-error:0.204722	train-error:0.167778
# [281]	eval-error:0.204778	train-error:0.167694
# [282]	eval-error:0.204889	train-error:0.167639
# [283]	eval-error:0.204889	train-error:0.167611
# [284]	eval-error:0.204778	train-error:0.167528
# [285]	eval-error:0.204889	train-error:0.167472
# [286]	eval-error:0.204944	train-error:0.167514
# [287]	eval-error:0.205	train-error:0.1675
# [288]	eval-error:0.205	train-error:0.167514
# [289]	eval-error:0.205111	train-error:0.167542
# [290]	eval-error:0.205167	train-error:0.167444
# [291]	eval-error:0.205167	train-error:0.167444
# [292]	eval-error:0.205167	train-error:0.167431
# [293]	eval-error:0.205111	train-error:0.167375
# [294]	eval-error:0.205333	train-error:0.167361
# [295]	eval-error:0.205333	train-error:0.167278
# [296]	eval-error:0.205333	train-error:0.167264
# [297]	eval-error:0.205222	train-error:0.167236
# [298]	eval-error:0.205222	train-error:0.167222
# [299]	eval-error:0.205167	train-error:0.166972
# [300]	eval-error:0.205111	train-error:0.166875
# [301]	eval-error:0.205056	train-error:0.166847
# [302]	eval-error:0.204889	train-error:0.166847
# [303]	eval-error:0.205167	train-error:0.166778
# [304]	eval-error:0.205333	train-error:0.166764
# [305]	eval-error:0.205167	train-error:0.166708
# [306]	eval-error:0.205111	train-error:0.166708
# [307]	eval-error:0.205056	train-error:0.166667
# [308]	eval-error:0.205	train-error:0.166542
# [309]	eval-error:0.205111	train-error:0.1665
# [310]	eval-error:0.204889	train-error:0.166444
# [311]	eval-error:0.204889	train-error:0.166431
# [312]	eval-error:0.204944	train-error:0.166431
# [313]	eval-error:0.204944	train-error:0.166389
# [314]	eval-error:0.204944	train-error:0.166403
# [315]	eval-error:0.204833	train-error:0.166417
# [316]	eval-error:0.204778	train-error:0.166403
# [317]	eval-error:0.204778	train-error:0.166403
# [318]	eval-error:0.204778	train-error:0.166361
# [319]	eval-error:0.204778	train-error:0.166278
# [320]	eval-error:0.204944	train-error:0.166208
# [321]	eval-error:0.204944	train-error:0.166208
# [322]	eval-error:0.205	train-error:0.166208
# [323]	eval-error:0.205	train-error:0.166208
# [324]	eval-error:0.204944	train-error:0.166194
# [325]	eval-error:0.204889	train-error:0.166181
# [326]	eval-error:0.204833	train-error:0.166111
# [327]	eval-error:0.204778	train-error:0.166097
# [328]	eval-error:0.204667	train-error:0.166056
# [329]	eval-error:0.204667	train-error:0.166056
# [330]	eval-error:0.204556	train-error:0.166
# [331]	eval-error:0.2045	train-error:0.166014
# [332]	eval-error:0.2045	train-error:0.166
# [333]	eval-error:0.2045	train-error:0.166
# [334]	eval-error:0.204556	train-error:0.165986
# [335]	eval-error:0.2045	train-error:0.165986
# [336]	eval-error:0.2045	train-error:0.165958
# [337]	eval-error:0.204389	train-error:0.165931
# [338]	eval-error:0.204444	train-error:0.165944
# [339]	eval-error:0.204556	train-error:0.165903
# [340]	eval-error:0.204611	train-error:0.165847
# [341]	eval-error:0.2045	train-error:0.165861
# [342]	eval-error:0.2045	train-error:0.165861
# [343]	eval-error:0.2045	train-error:0.165806
# [344]	eval-error:0.2045	train-error:0.165792
# [345]	eval-error:0.204389	train-error:0.165778
# [346]	eval-error:0.204333	train-error:0.165736
# [347]	eval-error:0.204222	train-error:0.165722
# [348]	eval-error:0.204167	train-error:0.165708
# [349]	eval-error:0.204222	train-error:0.165528
# [350]	eval-error:0.204111	train-error:0.165444
# [351]	eval-error:0.204111	train-error:0.165444
# [352]	eval-error:0.204111	train-error:0.165458
# [353]	eval-error:0.203944	train-error:0.165472
# [354]	eval-error:0.203944	train-error:0.165472
# [355]	eval-error:0.203944	train-error:0.165417
# [356]	eval-error:0.203778	train-error:0.165375
# [357]	eval-error:0.203667	train-error:0.165389
# [358]	eval-error:0.203778	train-error:0.165347
# [359]	eval-error:0.203778	train-error:0.165347
# [360]	eval-error:0.203944	train-error:0.165292
# [361]	eval-error:0.203778	train-error:0.165278
# [362]	eval-error:0.203889	train-error:0.165125
# [363]	eval-error:0.204111	train-error:0.165125
# [364]	eval-error:0.204167	train-error:0.165111
# [365]	eval-error:0.204278	train-error:0.165042
# [366]	eval-error:0.204278	train-error:0.165042
# [367]	eval-error:0.204333	train-error:0.165042
# [368]	eval-error:0.204444	train-error:0.164972
# [369]	eval-error:0.204444	train-error:0.164972
# [370]	eval-error:0.204389	train-error:0.164972
# [371]	eval-error:0.204389	train-error:0.164972
# [372]	eval-error:0.2045	train-error:0.164958
# [373]	eval-error:0.2045	train-error:0.164931
# [374]	eval-error:0.204278	train-error:0.164931
# [375]	eval-error:0.204389	train-error:0.164819
# [376]	eval-error:0.204389	train-error:0.164792
# [377]	eval-error:0.204333	train-error:0.164792
# [378]	eval-error:0.204389	train-error:0.164764
# [379]	eval-error:0.204389	train-error:0.164764
# [380]	eval-error:0.204444	train-error:0.164681
# [381]	eval-error:0.204222	train-error:0.164542
# [382]	eval-error:0.204056	train-error:0.164556
# [383]	eval-error:0.204056	train-error:0.164542
# [384]	eval-error:0.204	train-error:0.164542
# [385]	eval-error:0.204	train-error:0.164542
# [386]	eval-error:0.204	train-error:0.1645
# [387]	eval-error:0.204	train-error:0.164486
# [388]	eval-error:0.204	train-error:0.164472
# [389]	eval-error:0.204278	train-error:0.164375
# [390]	eval-error:0.204111	train-error:0.164347
# [391]	eval-error:0.204111	train-error:0.164333
# [392]	eval-error:0.204222	train-error:0.164333
# [393]	eval-error:0.204278	train-error:0.164333
# [394]	eval-error:0.204222	train-error:0.164361
# [395]	eval-error:0.204167	train-error:0.164333
# [396]	eval-error:0.204167	train-error:0.164333
# [397]	eval-error:0.204056	train-error:0.164181
# [398]	eval-error:0.204056	train-error:0.164181
# [399]	eval-error:0.204	train-error:0.164181
# [400]	eval-error:0.204	train-error:0.164153
# [401]	eval-error:0.203944	train-error:0.164153
# [402]	eval-error:0.203944	train-error:0.164139
# [403]	eval-error:0.203944	train-error:0.164111
# [404]	eval-error:0.204056	train-error:0.164097
# [405]	eval-error:0.204	train-error:0.164097
# [406]	eval-error:0.204	train-error:0.164083
# [407]	eval-error:0.204111	train-error:0.164042
# [408]	eval-error:0.203944	train-error:0.164
# [409]	eval-error:0.203944	train-error:0.163986
# [410]	eval-error:0.203889	train-error:0.163972
# [411]	eval-error:0.203944	train-error:0.163875
# [412]	eval-error:0.203944	train-error:0.163889
# [413]	eval-error:0.203889	train-error:0.163861
# [414]	eval-error:0.203889	train-error:0.163861
# [415]	eval-error:0.203889	train-error:0.163875
# [416]	eval-error:0.203944	train-error:0.163861
# [417]	eval-error:0.203944	train-error:0.163861
# [418]	eval-error:0.203889	train-error:0.163861
# [419]	eval-error:0.203889	train-error:0.163819
# [420]	eval-error:0.204111	train-error:0.163736
# [421]	eval-error:0.204167	train-error:0.163653
# [422]	eval-error:0.204056	train-error:0.163653
# [423]	eval-error:0.204	train-error:0.163653
# [424]	eval-error:0.203944	train-error:0.163611
# [425]	eval-error:0.203944	train-error:0.163611
# [426]	eval-error:0.203944	train-error:0.163569
# [427]	eval-error:0.203889	train-error:0.163486
# [428]	eval-error:0.203944	train-error:0.163472
# [429]	eval-error:0.204	train-error:0.163458
# [430]	eval-error:0.204	train-error:0.163458
# [431]	eval-error:0.204	train-error:0.163458
# [432]	eval-error:0.203889	train-error:0.163472
# [433]	eval-error:0.203833	train-error:0.163444
# [434]	eval-error:0.203778	train-error:0.163458
# [435]	eval-error:0.203833	train-error:0.163444
# [436]	eval-error:0.203833	train-error:0.163458
# [437]	eval-error:0.203778	train-error:0.163458
# [438]	eval-error:0.203778	train-error:0.163458
# [439]	eval-error:0.203778	train-error:0.163458
# [440]	eval-error:0.203833	train-error:0.163431
# [441]	eval-error:0.203889	train-error:0.163306
# [442]	eval-error:0.203944	train-error:0.163292
# [443]	eval-error:0.204056	train-error:0.163278
# [444]	eval-error:0.204056	train-error:0.163264
# [445]	eval-error:0.203833	train-error:0.163236
# [446]	eval-error:0.203556	train-error:0.163181
# [447]	eval-error:0.203444	train-error:0.163181
# [448]	eval-error:0.203444	train-error:0.163153
# [449]	eval-error:0.2035	train-error:0.163153
# [450]	eval-error:0.203444	train-error:0.163153
# [451]	eval-error:0.2035	train-error:0.163153
# [452]	eval-error:0.203389	train-error:0.163125
# [453]	eval-error:0.203333	train-error:0.163083
# [454]	eval-error:0.203333	train-error:0.163056
# [455]	eval-error:0.203333	train-error:0.163042
# [456]	eval-error:0.203667	train-error:0.162986
# [457]	eval-error:0.203611	train-error:0.162972
# [458]	eval-error:0.203611	train-error:0.162917
# [459]	eval-error:0.203722	train-error:0.162889
# [460]	eval-error:0.203667	train-error:0.162889
# [461]	eval-error:0.203722	train-error:0.162889
# [462]	eval-error:0.203778	train-error:0.162792
# [463]	eval-error:0.203778	train-error:0.162778
# [464]	eval-error:0.203667	train-error:0.162806
# [465]	eval-error:0.203667	train-error:0.162806
# [466]	eval-error:0.203556	train-error:0.162806
# [467]	eval-error:0.203611	train-error:0.162764
# [468]	eval-error:0.203611	train-error:0.162778
# [469]	eval-error:0.203611	train-error:0.162778
# [470]	eval-error:0.203611	train-error:0.162764
# [471]	eval-error:0.203667	train-error:0.16275
# [472]	eval-error:0.203611	train-error:0.162736
# [473]	eval-error:0.203611	train-error:0.162722
# [474]	eval-error:0.203611	train-error:0.162722
# [475]	eval-error:0.203611	train-error:0.162708
# [476]	eval-error:0.203611	train-error:0.162708
# [477]	eval-error:0.203611	train-error:0.162708
# [478]	eval-error:0.203556	train-error:0.162694
# [479]	eval-error:0.2035	train-error:0.162694
# [480]	eval-error:0.203444	train-error:0.162681
# [481]	eval-error:0.2035	train-error:0.162681
# [482]	eval-error:0.2035	train-error:0.162681
# [483]	eval-error:0.2035	train-error:0.162667
# [484]	eval-error:0.2035	train-error:0.162667
# [485]	eval-error:0.203556	train-error:0.162681
# [486]	eval-error:0.203556	train-error:0.162681
# [487]	eval-error:0.203667	train-error:0.162694
# [488]	eval-error:0.203722	train-error:0.162708
# [489]	eval-error:0.203611	train-error:0.162639
# [490]	eval-error:0.203611	train-error:0.162653
# [491]	eval-error:0.203611	train-error:0.162653
# [492]	eval-error:0.203611	train-error:0.162653
# [493]	eval-error:0.203611	train-error:0.162653
# [494]	eval-error:0.203611	train-error:0.162653
# [495]	eval-error:0.203611	train-error:0.162625
# [496]	eval-error:0.203611	train-error:0.162597
# [497]	eval-error:0.203556	train-error:0.162639
# [498]	eval-error:0.203611	train-error:0.162556
# [499]	eval-error:0.203444	train-error:0.1625
# [500]	eval-error:0.203389	train-error:0.162486
# [501]	eval-error:0.203667	train-error:0.162403
# [502]	eval-error:0.2035	train-error:0.162403
# [503]	eval-error:0.203444	train-error:0.162403
# [504]	eval-error:0.2035	train-error:0.162389
# [505]	eval-error:0.2035	train-error:0.162375
# [506]	eval-error:0.2035	train-error:0.162375
# [507]	eval-error:0.203444	train-error:0.162375
# [508]	eval-error:0.2035	train-error:0.162403
# [509]	eval-error:0.203722	train-error:0.162389
# [510]	eval-error:0.203444	train-error:0.162306
# [511]	eval-error:0.203444	train-error:0.162292
# [512]	eval-error:0.203444	train-error:0.162278
# [513]	eval-error:0.203444	train-error:0.162222
# [514]	eval-error:0.203444	train-error:0.162208
# [515]	eval-error:0.203444	train-error:0.162208
# [516]	eval-error:0.203333	train-error:0.162181
# [517]	eval-error:0.203333	train-error:0.162167
# [518]	eval-error:0.203389	train-error:0.162181
# [519]	eval-error:0.203333	train-error:0.162181
# [520]	eval-error:0.203222	train-error:0.162208
# [521]	eval-error:0.203278	train-error:0.162194
# [522]	eval-error:0.203278	train-error:0.162194
# [523]	eval-error:0.203333	train-error:0.162181
# [524]	eval-error:0.203167	train-error:0.162167
# [525]	eval-error:0.203167	train-error:0.162167
# [526]	eval-error:0.203222	train-error:0.162125
# [527]	eval-error:0.203167	train-error:0.162111
# [528]	eval-error:0.203167	train-error:0.162083
# [529]	eval-error:0.203167	train-error:0.162083
# [530]	eval-error:0.203111	train-error:0.162083
# [531]	eval-error:0.203222	train-error:0.162056
# [532]	eval-error:0.203111	train-error:0.162028
# [533]	eval-error:0.203111	train-error:0.162
# [534]	eval-error:0.203	train-error:0.161903
# [535]	eval-error:0.203056	train-error:0.161861
# [536]	eval-error:0.203	train-error:0.161806
# [537]	eval-error:0.202944	train-error:0.161736
# [538]	eval-error:0.202778	train-error:0.161667
# [539]	eval-error:0.202722	train-error:0.161653
# [540]	eval-error:0.202889	train-error:0.161639
# [541]	eval-error:0.202889	train-error:0.161625
# [542]	eval-error:0.202944	train-error:0.161625
# [543]	eval-error:0.203	train-error:0.161625
# [544]	eval-error:0.203056	train-error:0.161611
# [545]	eval-error:0.203111	train-error:0.161597
# [546]	eval-error:0.203056	train-error:0.161583
# [547]	eval-error:0.203056	train-error:0.161528
# [548]	eval-error:0.203056	train-error:0.161528
# [549]	eval-error:0.203167	train-error:0.161528
# [550]	eval-error:0.203222	train-error:0.161542
# [551]	eval-error:0.203167	train-error:0.161458
# [552]	eval-error:0.203333	train-error:0.161458
# [553]	eval-error:0.2035	train-error:0.161375
# [554]	eval-error:0.203222	train-error:0.161333
# [555]	eval-error:0.203111	train-error:0.161333
# [556]	eval-error:0.203056	train-error:0.161333
# [557]	eval-error:0.203111	train-error:0.161347
# [558]	eval-error:0.203167	train-error:0.161333
# [559]	eval-error:0.203167	train-error:0.161333
# [560]	eval-error:0.203111	train-error:0.161306
# [561]	eval-error:0.203111	train-error:0.161292
# [562]	eval-error:0.203056	train-error:0.161319
# [563]	eval-error:0.203056	train-error:0.161306
# [564]	eval-error:0.203278	train-error:0.161264
# [565]	eval-error:0.203278	train-error:0.16125
# [566]	eval-error:0.203278	train-error:0.161194
# [567]	eval-error:0.203278	train-error:0.161194
# [568]	eval-error:0.203222	train-error:0.161194
# [569]	eval-error:0.203167	train-error:0.161194
# [570]	eval-error:0.203167	train-error:0.161194
# [571]	eval-error:0.203222	train-error:0.161194
# [572]	eval-error:0.203222	train-error:0.161194
# [573]	eval-error:0.203222	train-error:0.161167
# [574]	eval-error:0.203222	train-error:0.161153
# [575]	eval-error:0.203167	train-error:0.161153
# [576]	eval-error:0.203056	train-error:0.161125
# [577]	eval-error:0.203111	train-error:0.161125
# [578]	eval-error:0.203111	train-error:0.161125
# [579]	eval-error:0.203111	train-error:0.161111
# [580]	eval-error:0.203056	train-error:0.161111
# [581]	eval-error:0.202889	train-error:0.161097
# [582]	eval-error:0.202944	train-error:0.161083
# [583]	eval-error:0.203	train-error:0.161069
# [584]	eval-error:0.203056	train-error:0.161069
# [585]	eval-error:0.202944	train-error:0.161028
# [586]	eval-error:0.202944	train-error:0.161028
# [587]	eval-error:0.202944	train-error:0.161028
# [588]	eval-error:0.202944	train-error:0.161028
# [589]	eval-error:0.202944	train-error:0.161028
# [590]	eval-error:0.202889	train-error:0.161028
# [591]	eval-error:0.203	train-error:0.161014
# [592]	eval-error:0.203	train-error:0.161
# [593]	eval-error:0.203111	train-error:0.160958
# [594]	eval-error:0.203111	train-error:0.160944
# [595]	eval-error:0.203111	train-error:0.160944
# [596]	eval-error:0.203111	train-error:0.160931
# [597]	eval-error:0.203	train-error:0.160903
# [598]	eval-error:0.203	train-error:0.160903
# [599]	eval-error:0.203	train-error:0.160903
# [600]	eval-error:0.203222	train-error:0.160903
# [601]	eval-error:0.203056	train-error:0.160875
# [602]	eval-error:0.203056	train-error:0.160889
# [603]	eval-error:0.203	train-error:0.160889
# [604]	eval-error:0.202944	train-error:0.160889
# [605]	eval-error:0.202944	train-error:0.160875
# [606]	eval-error:0.202944	train-error:0.160875
# [607]	eval-error:0.202944	train-error:0.160875
# [608]	eval-error:0.202944	train-error:0.160875
# [609]	eval-error:0.203111	train-error:0.160861
# [610]	eval-error:0.203111	train-error:0.160861
# [611]	eval-error:0.203111	train-error:0.160806
# [612]	eval-error:0.203111	train-error:0.160806
# [613]	eval-error:0.203111	train-error:0.160806
# [614]	eval-error:0.203056	train-error:0.160806
# [615]	eval-error:0.203056	train-error:0.160806
# [616]	eval-error:0.203167	train-error:0.160806
# [617]	eval-error:0.203167	train-error:0.160806
# [618]	eval-error:0.203167	train-error:0.160764
# [619]	eval-error:0.203167	train-error:0.16075
# [620]	eval-error:0.203222	train-error:0.16075
# [621]	eval-error:0.203278	train-error:0.16075
# [622]	eval-error:0.203167	train-error:0.160722
# [623]	eval-error:0.203222	train-error:0.160722
# [624]	eval-error:0.203056	train-error:0.160694
# [625]	eval-error:0.203	train-error:0.160694
# [626]	eval-error:0.203056	train-error:0.160694
# [627]	eval-error:0.203111	train-error:0.160681
# [628]	eval-error:0.203167	train-error:0.160681
# [629]	eval-error:0.203167	train-error:0.160681
# [630]	eval-error:0.203167	train-error:0.160681
# [631]	eval-error:0.203222	train-error:0.160681
# [632]	eval-error:0.203222	train-error:0.160667
# [633]	eval-error:0.203389	train-error:0.160667
# [634]	eval-error:0.203389	train-error:0.160667
# [635]	eval-error:0.203389	train-error:0.160667
# [636]	eval-error:0.203389	train-error:0.160667
# [637]	eval-error:0.203389	train-error:0.160653
# [638]	eval-error:0.203444	train-error:0.160653
# [639]	eval-error:0.203444	train-error:0.160653
# [640]	eval-error:0.203389	train-error:0.160625
# [641]	eval-error:0.203278	train-error:0.160583
# [642]	eval-error:0.203278	train-error:0.160583
# [643]	eval-error:0.203278	train-error:0.160583
# [644]	eval-error:0.203278	train-error:0.160583
# [645]	eval-error:0.203333	train-error:0.160556
# [646]	eval-error:0.203333	train-error:0.160556
# [647]	eval-error:0.203389	train-error:0.160556
# [648]	eval-error:0.203389	train-error:0.160569
# [649]	eval-error:0.203389	train-error:0.160556
# [650]	eval-error:0.203278	train-error:0.160542
# [651]	eval-error:0.203278	train-error:0.160556
# [652]	eval-error:0.203222	train-error:0.160556
# [653]	eval-error:0.203222	train-error:0.160528
# [654]	eval-error:0.203222	train-error:0.1605
# [655]	eval-error:0.203167	train-error:0.160486
# [656]	eval-error:0.203167	train-error:0.160486
# [657]	eval-error:0.203167	train-error:0.160417
# [658]	eval-error:0.203167	train-error:0.160417
# [659]	eval-error:0.203111	train-error:0.160417
# [660]	eval-error:0.203111	train-error:0.160403
# [661]	eval-error:0.203056	train-error:0.160403
# [662]	eval-error:0.203056	train-error:0.160389
# [663]	eval-error:0.203056	train-error:0.160361
# [664]	eval-error:0.203167	train-error:0.160361
# [665]	eval-error:0.203278	train-error:0.160347
# [666]	eval-error:0.203278	train-error:0.160319
# [667]	eval-error:0.203278	train-error:0.160333
# [668]	eval-error:0.203333	train-error:0.160306
# [669]	eval-error:0.203333	train-error:0.160306
# [670]	eval-error:0.203278	train-error:0.160306
# [671]	eval-error:0.203333	train-error:0.160292
# [672]	eval-error:0.203278	train-error:0.160278
# [673]	eval-error:0.203389	train-error:0.160278
# [674]	eval-error:0.203389	train-error:0.160278
# [675]	eval-error:0.203389	train-error:0.160278
# [676]	eval-error:0.203389	train-error:0.160278
# [677]	eval-error:0.203444	train-error:0.160278
# [678]	eval-error:0.203389	train-error:0.160278
# [679]	eval-error:0.203389	train-error:0.160278
# [680]	eval-error:0.203389	train-error:0.160278
# [681]	eval-error:0.203333	train-error:0.160264
# [682]	eval-error:0.203333	train-error:0.16025
# [683]	eval-error:0.203278	train-error:0.16025
# [684]	eval-error:0.203278	train-error:0.16025
# [685]	eval-error:0.203278	train-error:0.160236
# [686]	eval-error:0.203333	train-error:0.160236
# [687]	eval-error:0.203333	train-error:0.160236
# [688]	eval-error:0.203333	train-error:0.160222
# [689]	eval-error:0.203278	train-error:0.160222
# [690]	eval-error:0.203278	train-error:0.160222
# [691]	eval-error:0.203278	train-error:0.160208
# [692]	eval-error:0.203278	train-error:0.160208
# [693]	eval-error:0.203278	train-error:0.160208
# [694]	eval-error:0.203278	train-error:0.160222
# [695]	eval-error:0.203278	train-error:0.160208
# [696]	eval-error:0.203222	train-error:0.160222
# [697]	eval-error:0.203222	train-error:0.160208
# [698]	eval-error:0.203278	train-error:0.160236
# [699]	eval-error:0.203278	train-error:0.160236
# [700]	eval-error:0.203278	train-error:0.160236
# [701]	eval-error:0.203389	train-error:0.160236
# [702]	eval-error:0.203333	train-error:0.160236
# [703]	eval-error:0.203333	train-error:0.160208
# [704]	eval-error:0.203333	train-error:0.160208
# [705]	eval-error:0.203389	train-error:0.160208
# [706]	eval-error:0.203389	train-error:0.160181
# [707]	eval-error:0.203167	train-error:0.160125
# [708]	eval-error:0.203278	train-error:0.160111
# [709]	eval-error:0.203222	train-error:0.160111
# [710]	eval-error:0.203222	train-error:0.160111
# [711]	eval-error:0.203222	train-error:0.160097
# [712]	eval-error:0.203222	train-error:0.160097
# [713]	eval-error:0.203222	train-error:0.160097
# [714]	eval-error:0.203222	train-error:0.160097
# [715]	eval-error:0.203222	train-error:0.160083
# [716]	eval-error:0.203222	train-error:0.160083
# [717]	eval-error:0.203222	train-error:0.160083
# [718]	eval-error:0.203222	train-error:0.160083
# [719]	eval-error:0.203222	train-error:0.160083
# [720]	eval-error:0.203222	train-error:0.160083
# [721]	eval-error:0.203111	train-error:0.160083
# [722]	eval-error:0.203167	train-error:0.160083
# [723]	eval-error:0.203111	train-error:0.160083
# [724]	eval-error:0.203111	train-error:0.160083
# [725]	eval-error:0.203111	train-error:0.160083
# [726]	eval-error:0.203111	train-error:0.160083
# [727]	eval-error:0.203111	train-error:0.160083
# [728]	eval-error:0.203111	train-error:0.160083
# [729]	eval-error:0.203222	train-error:0.160083
# [730]	eval-error:0.203222	train-error:0.160083
# [731]	eval-error:0.203333	train-error:0.160083
# [732]	eval-error:0.203333	train-error:0.160083
# [733]	eval-error:0.203333	train-error:0.160083
# [734]	eval-error:0.203278	train-error:0.160111
# [735]	eval-error:0.203278	train-error:0.160111
# [736]	eval-error:0.203222	train-error:0.160111
# [737]	eval-error:0.203222	train-error:0.160083
# [738]	eval-error:0.203278	train-error:0.160083
# [739]	eval-error:0.203167	train-error:0.160083
# [740]	eval-error:0.203167	train-error:0.160083
# [741]	eval-error:0.203167	train-error:0.160083
# [742]	eval-error:0.203222	train-error:0.160056
# [743]	eval-error:0.203167	train-error:0.160056
# [744]	eval-error:0.203111	train-error:0.160042
# [745]	eval-error:0.203111	train-error:0.160042
# [746]	eval-error:0.203056	train-error:0.160014
# [747]	eval-error:0.203056	train-error:0.16
# [748]	eval-error:0.203056	train-error:0.159972
# [749]	eval-error:0.203056	train-error:0.159972
# [750]	eval-error:0.203056	train-error:0.159972
# [751]	eval-error:0.203056	train-error:0.159972
# [752]	eval-error:0.203167	train-error:0.159972
# [753]	eval-error:0.203167	train-error:0.16
# [754]	eval-error:0.203056	train-error:0.160014
# [755]	eval-error:0.203	train-error:0.16
# [756]	eval-error:0.202889	train-error:0.16
# [757]	eval-error:0.202889	train-error:0.16
# [758]	eval-error:0.202833	train-error:0.16
# [759]	eval-error:0.203	train-error:0.160014
# [760]	eval-error:0.203	train-error:0.160014
# [761]	eval-error:0.203	train-error:0.160014
# [762]	eval-error:0.203	train-error:0.16
# [763]	eval-error:0.203	train-error:0.16
# [764]	eval-error:0.203056	train-error:0.16
# [765]	eval-error:0.203111	train-error:0.159986
# [766]	eval-error:0.203111	train-error:0.159986
# [767]	eval-error:0.203	train-error:0.160014
# [768]	eval-error:0.203	train-error:0.160014
# [769]	eval-error:0.202944	train-error:0.159986
# [770]	eval-error:0.203	train-error:0.159986
# [771]	eval-error:0.202944	train-error:0.159986
# [772]	eval-error:0.202944	train-error:0.159986
# [773]	eval-error:0.202889	train-error:0.159986
# [774]	eval-error:0.202944	train-error:0.159958
# [775]	eval-error:0.202944	train-error:0.159972
# [776]	eval-error:0.203	train-error:0.159958
# [777]	eval-error:0.202944	train-error:0.159972
# [778]	eval-error:0.202944	train-error:0.159972
# [779]	eval-error:0.202889	train-error:0.159972
# [780]	eval-error:0.202833	train-error:0.159917
# [781]	eval-error:0.202944	train-error:0.159875
# [782]	eval-error:0.202778	train-error:0.159847
# [783]	eval-error:0.202722	train-error:0.159861
# [784]	eval-error:0.202778	train-error:0.159861
# [785]	eval-error:0.202833	train-error:0.159875
# [786]	eval-error:0.202722	train-error:0.159875
# [787]	eval-error:0.202722	train-error:0.159875
# [788]	eval-error:0.202667	train-error:0.159833
# [789]	eval-error:0.202444	train-error:0.159833
# [790]	eval-error:0.202611	train-error:0.159819
# [791]	eval-error:0.202444	train-error:0.159792
# [792]	eval-error:0.2025	train-error:0.159792
# [793]	eval-error:0.202667	train-error:0.15975
# [794]	eval-error:0.202778	train-error:0.159708
# [795]	eval-error:0.202778	train-error:0.159708
# [796]	eval-error:0.202889	train-error:0.159708
# [797]	eval-error:0.203	train-error:0.159667
# [798]	eval-error:0.202944	train-error:0.159667
# [799]	eval-error:0.202944	train-error:0.159681
# [800]	eval-error:0.202889	train-error:0.159681
# [801]	eval-error:0.202889	train-error:0.159681
# [802]	eval-error:0.202833	train-error:0.159639
# [803]	eval-error:0.202889	train-error:0.159639
# [804]	eval-error:0.202889	train-error:0.159639
# [805]	eval-error:0.202833	train-error:0.159639
# [806]	eval-error:0.202833	train-error:0.159625
# [807]	eval-error:0.202944	train-error:0.159625
# [808]	eval-error:0.202944	train-error:0.159569
# [809]	eval-error:0.203	train-error:0.159528
# [810]	eval-error:0.203	train-error:0.159514
# [811]	eval-error:0.203	train-error:0.159514
# [812]	eval-error:0.202833	train-error:0.1595
# [813]	eval-error:0.202833	train-error:0.159486
# [814]	eval-error:0.202833	train-error:0.159486
# [815]	eval-error:0.202833	train-error:0.159486
# [816]	eval-error:0.202944	train-error:0.159486
# [817]	eval-error:0.202944	train-error:0.159486
# [818]	eval-error:0.202833	train-error:0.159486
# [819]	eval-error:0.202833	train-error:0.159486
# [820]	eval-error:0.202778	train-error:0.159486
# [821]	eval-error:0.202833	train-error:0.159486
# [822]	eval-error:0.202833	train-error:0.159486
# [823]	eval-error:0.202833	train-error:0.159486
# [824]	eval-error:0.202833	train-error:0.159486
# [825]	eval-error:0.202833	train-error:0.159486
# [826]	eval-error:0.202833	train-error:0.159486
# [827]	eval-error:0.202833	train-error:0.159486
# [828]	eval-error:0.202778	train-error:0.159472
# [829]	eval-error:0.202833	train-error:0.159486
# [830]	eval-error:0.202833	train-error:0.1595
# [831]	eval-error:0.202833	train-error:0.1595
# [832]	eval-error:0.202833	train-error:0.1595
# [833]	eval-error:0.202778	train-error:0.1595
# [834]	eval-error:0.202778	train-error:0.1595
# [835]	eval-error:0.202778	train-error:0.1595
# [836]	eval-error:0.202722	train-error:0.159528
# [837]	eval-error:0.202722	train-error:0.159528
# [838]	eval-error:0.202722	train-error:0.159528
# [839]	eval-error:0.202722	train-error:0.159514
# [840]	eval-error:0.202722	train-error:0.1595
# [841]	eval-error:0.202722	train-error:0.159486
# [842]	eval-error:0.202722	train-error:0.159486
# [843]	eval-error:0.202667	train-error:0.159514
# [844]	eval-error:0.202611	train-error:0.159514
# [845]	eval-error:0.202611	train-error:0.159514
# [846]	eval-error:0.202778	train-error:0.1595
# [847]	eval-error:0.202667	train-error:0.1595
# [848]	eval-error:0.202667	train-error:0.159514
# [849]	eval-error:0.202556	train-error:0.159514
# [850]	eval-error:0.202556	train-error:0.159514
# [851]	eval-error:0.202667	train-error:0.159514
# [852]	eval-error:0.202556	train-error:0.1595
# [853]	eval-error:0.2025	train-error:0.159486
# [854]	eval-error:0.202444	train-error:0.159472
# [855]	eval-error:0.202556	train-error:0.159458
# [856]	eval-error:0.202611	train-error:0.159444
# [857]	eval-error:0.202722	train-error:0.159444
# [858]	eval-error:0.202778	train-error:0.159444
# [859]	eval-error:0.202889	train-error:0.159417
# [860]	eval-error:0.203056	train-error:0.159389
# [861]	eval-error:0.203056	train-error:0.159389
# [862]	eval-error:0.203	train-error:0.159375
# [863]	eval-error:0.203111	train-error:0.159375
# [864]	eval-error:0.203111	train-error:0.159375
# [865]	eval-error:0.203056	train-error:0.159375
# [866]	eval-error:0.203056	train-error:0.159361
# [867]	eval-error:0.203111	train-error:0.159361
# [868]	eval-error:0.203111	train-error:0.159361
# [869]	eval-error:0.203111	train-error:0.159361
# [870]	eval-error:0.203167	train-error:0.159361
# [871]	eval-error:0.203222	train-error:0.159361
# [872]	eval-error:0.203111	train-error:0.159361
# [873]	eval-error:0.203111	train-error:0.159361
# [874]	eval-error:0.203111	train-error:0.159347
# [875]	eval-error:0.203056	train-error:0.159347
# [876]	eval-error:0.203111	train-error:0.159347
# [877]	eval-error:0.203222	train-error:0.159333
# [878]	eval-error:0.203167	train-error:0.159333
# [879]	eval-error:0.203222	train-error:0.159333
# [880]	eval-error:0.203333	train-error:0.159319
# [881]	eval-error:0.203389	train-error:0.159306
# [882]	eval-error:0.203444	train-error:0.159306
# [883]	eval-error:0.2035	train-error:0.159292
# [884]	eval-error:0.2035	train-error:0.159292
# [885]	eval-error:0.2035	train-error:0.159292
# [886]	eval-error:0.203611	train-error:0.159292
# [887]	eval-error:0.203611	train-error:0.159306
# [888]	eval-error:0.203611	train-error:0.159306
# [889]	eval-error:0.203611	train-error:0.159319
# [890]	eval-error:0.203444	train-error:0.159292
# [891]	eval-error:0.203444	train-error:0.159292
# [892]	eval-error:0.203444	train-error:0.159306
# [893]	eval-error:0.2035	train-error:0.159306
# [894]	eval-error:0.203333	train-error:0.159306
# [895]	eval-error:0.203333	train-error:0.159306
# [896]	eval-error:0.203333	train-error:0.159306
# [897]	eval-error:0.203278	train-error:0.159292
# [898]	eval-error:0.203333	train-error:0.159292
# [899]	eval-error:0.203333	train-error:0.159292
# [900]	eval-error:0.203278	train-error:0.159292
# [901]	eval-error:0.203333	train-error:0.159292
# [902]	eval-error:0.203389	train-error:0.159306
# [903]	eval-error:0.203389	train-error:0.159306
# [904]	eval-error:0.203333	train-error:0.159306
# [905]	eval-error:0.203333	train-error:0.159306
# [906]	eval-error:0.203278	train-error:0.159306
# [907]	eval-error:0.203222	train-error:0.159306
# [908]	eval-error:0.203389	train-error:0.159306
# [909]	eval-error:0.203389	train-error:0.159306
# [910]	eval-error:0.203389	train-error:0.159306
# [911]	eval-error:0.203444	train-error:0.159292
# [912]	eval-error:0.203444	train-error:0.159292
# [913]	eval-error:0.203444	train-error:0.159292
# [914]	eval-error:0.203333	train-error:0.159264
# [915]	eval-error:0.203333	train-error:0.159264
# [916]	eval-error:0.203222	train-error:0.15925
# [917]	eval-error:0.203111	train-error:0.159236
# [918]	eval-error:0.203111	train-error:0.159208
# [919]	eval-error:0.202889	train-error:0.159208
# [920]	eval-error:0.202944	train-error:0.159208
# [921]	eval-error:0.203056	train-error:0.159208
# [922]	eval-error:0.203056	train-error:0.159208
# [923]	eval-error:0.203111	train-error:0.159208
# [924]	eval-error:0.203111	train-error:0.159208
# [925]	eval-error:0.203111	train-error:0.159208
# [926]	eval-error:0.203444	train-error:0.159208
# [927]	eval-error:0.203389	train-error:0.159208
# [928]	eval-error:0.203389	train-error:0.159181
# [929]	eval-error:0.203389	train-error:0.159181
# [930]	eval-error:0.203389	train-error:0.159181
# [931]	eval-error:0.203167	train-error:0.159181
# [932]	eval-error:0.203278	train-error:0.159167
# [933]	eval-error:0.203333	train-error:0.159167
# [934]	eval-error:0.203389	train-error:0.159153
# [935]	eval-error:0.203444	train-error:0.159153
# [936]	eval-error:0.203444	train-error:0.159153
# [937]	eval-error:0.203444	train-error:0.159153
# [938]	eval-error:0.2035	train-error:0.159153
# [939]	eval-error:0.203444	train-error:0.159139
# [940]	eval-error:0.203444	train-error:0.159139
# [941]	eval-error:0.203444	train-error:0.159139
# [942]	eval-error:0.203444	train-error:0.159139
# [943]	eval-error:0.203444	train-error:0.159153
# [944]	eval-error:0.203389	train-error:0.159153
# [945]	eval-error:0.203389	train-error:0.159153
# [946]	eval-error:0.203389	train-error:0.159139
# [947]	eval-error:0.203389	train-error:0.159139
# [948]	eval-error:0.203111	train-error:0.159139
# [949]	eval-error:0.203111	train-error:0.159139
# [950]	eval-error:0.203111	train-error:0.159139
# [951]	eval-error:0.203222	train-error:0.159139
# [952]	eval-error:0.203222	train-error:0.159125
# [953]	eval-error:0.203222	train-error:0.159125
# [954]	eval-error:0.203444	train-error:0.159125
# [955]	eval-error:0.203389	train-error:0.159125
# [956]	eval-error:0.203389	train-error:0.159125
# [957]	eval-error:0.203389	train-error:0.159111
# [958]	eval-error:0.203389	train-error:0.159097
# [959]	eval-error:0.203389	train-error:0.159097
# [960]	eval-error:0.203389	train-error:0.159097
# [961]	eval-error:0.203389	train-error:0.159097
# [962]	eval-error:0.203444	train-error:0.159083
# [963]	eval-error:0.2035	train-error:0.159083
# [964]	eval-error:0.203444	train-error:0.159083
# [965]	eval-error:0.203389	train-error:0.159069
# [966]	eval-error:0.203389	train-error:0.159069
# [967]	eval-error:0.203389	train-error:0.159069
# [968]	eval-error:0.203389	train-error:0.159069
# [969]	eval-error:0.2035	train-error:0.159069
# [970]	eval-error:0.203389	train-error:0.159069
# [971]	eval-error:0.203389	train-error:0.159069
# [972]	eval-error:0.203333	train-error:0.159056
# [973]	eval-error:0.203389	train-error:0.159056
# [974]	eval-error:0.203222	train-error:0.159042
# [975]	eval-error:0.203222	train-error:0.159042
# [976]	eval-error:0.203222	train-error:0.159042
# [977]	eval-error:0.203222	train-error:0.159042
# [978]	eval-error:0.203167	train-error:0.159042
# [979]	eval-error:0.203167	train-error:0.159042
# [980]	eval-error:0.202944	train-error:0.159042
# [981]	eval-error:0.202944	train-error:0.159042
# [982]	eval-error:0.202833	train-error:0.159028
# [983]	eval-error:0.202833	train-error:0.159014
# [984]	eval-error:0.202889	train-error:0.159014
# [985]	eval-error:0.202833	train-error:0.159014
# [986]	eval-error:0.202778	train-error:0.159
# [987]	eval-error:0.202889	train-error:0.159
# [988]	eval-error:0.202889	train-error:0.159
# [989]	eval-error:0.202722	train-error:0.159
# [990]	eval-error:0.202667	train-error:0.158986
# [991]	eval-error:0.202889	train-error:0.158972
# [992]	eval-error:0.202722	train-error:0.158972
# [993]	eval-error:0.202722	train-error:0.158972
# [994]	eval-error:0.202722	train-error:0.158972
# [995]	eval-error:0.202722	train-error:0.158958
# [996]	eval-error:0.202722	train-error:0.158958
# [997]	eval-error:0.202722	train-error:0.158958
# [998]	eval-error:0.202778	train-error:0.158958
# [999]	eval-error:0.202778	train-error:0.158958

# %%
xgb_prob_preds = bst.predict(dtest)
xgb_preds = np.asarray([1 if line > 0.5 else 0 for line in xgb_prob_preds]).astype('int64')

# %%
print(classification_report(y_test, rf_preds))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.92      0.87      0.89      8980
#           1       0.87      0.92      0.90      9020
#
# avg / total       0.90      0.90      0.90     18000

# %% [markdown]
# ### Neural Network Model for KnownUnknown Class Detection (3 Hidden Layers)
# #### Using relu as activation functions for hidden layers due to its robustness and the absence of vanishing gradient problem when using it. Sigmoid is used as the activation function for the output as it is a binary classification problem.
#
# #### Loss function of binary crossentropy is used as it is a binary problem.

# %%
model_name = 'known_classifier_nn.h5'

nn_model = Sequential()

nn_model.add(Dense(250, activation='relu', input_shape=tuple(x.shape[1:])))
nn_model.add(Dropout(0.5))
nn_model.add(Dense(500, activation='relu'))
nn_model.add(Dropout(0.5))
nn_model.add(Dense(1000, activation='relu'))
nn_model.add(Dropout(0.5))
nn_model.add(Dense(500, activation='relu'))
nn_model.add(Dropout(0.5))
nn_model.add(Dense(250, activation='relu'))
nn_model.add(Dropout(0.5))
nn_model.add(Dense(1, activation='sigmoid'))

op = optimizers.Adam(lr=0.0001)

nn_model.compile(optimizer=op, metrics=['accuracy'], loss='binary_crossentropy')

save_checkpoint = ModelCheckpoint(model_name, save_best_only=True, verbose=1)
early_stop = EarlyStopping(min_delta=0.01, patience=500, verbose=1, mode='min')

nn_model.fit(x_train, y_train, epochs=50000, batch_size=16, verbose=2, 
             class_weight=class_weights, shuffle=True, validation_split=0.2, callbacks=[save_checkpoint, early_stop])
# Out:
# Train on 57600 samples, validate on 14400 samples
# Epoch 1/50000
#  - 122s - loss: 0.6868 - acc: 0.5554 - val_loss: 0.6709 - val_acc: 0.5875
#
# Epoch 00001: val_loss improved from inf to 0.67086, saving model to known_classifier_nn.h5
# Epoch 2/50000
#  - 123s - loss: 0.6740 - acc: 0.5789 - val_loss: 0.6626 - val_acc: 0.6030
#
# Epoch 00002: val_loss improved from 0.67086 to 0.66258, saving model to known_classifier_nn.h5
# Epoch 3/50000
#  - 115s - loss: 0.6677 - acc: 0.5895 - val_loss: 0.6559 - val_acc: 0.6033
#
# Epoch 00003: val_loss improved from 0.66258 to 0.65590, saving model to known_classifier_nn.h5
# Epoch 4/50000
#  - 120s - loss: 0.6592 - acc: 0.5960 - val_loss: 0.6382 - val_acc: 0.6188
#
# Epoch 00004: val_loss improved from 0.65590 to 0.63821, saving model to known_classifier_nn.h5
# Epoch 5/50000
#  - 120s - loss: 0.6442 - acc: 0.6060 - val_loss: 0.6275 - val_acc: 0.6284
#
# Epoch 00005: val_loss improved from 0.63821 to 0.62753, saving model to known_classifier_nn.h5
# Epoch 6/50000
#  - 121s - loss: 0.6340 - acc: 0.6096 - val_loss: 0.6191 - val_acc: 0.6281
#
# Epoch 00006: val_loss improved from 0.62753 to 0.61909, saving model to known_classifier_nn.h5
# Epoch 7/50000
#  - 122s - loss: 0.6274 - acc: 0.6165 - val_loss: 0.6148 - val_acc: 0.6384
#
# Epoch 00007: val_loss improved from 0.61909 to 0.61483, saving model to known_classifier_nn.h5
# Epoch 8/50000
#  - 115s - loss: 0.6238 - acc: 0.6237 - val_loss: 0.6129 - val_acc: 0.6378
#
# Epoch 00008: val_loss improved from 0.61483 to 0.61286, saving model to known_classifier_nn.h5
# Epoch 9/50000
#  - 114s - loss: 0.6213 - acc: 0.6253 - val_loss: 0.6131 - val_acc: 0.6419
#
# Epoch 00009: val_loss did not improve
# Epoch 10/50000
#  - 119s - loss: 0.6192 - acc: 0.6285 - val_loss: 0.6088 - val_acc: 0.6426
#
# Epoch 00010: val_loss improved from 0.61286 to 0.60884, saving model to known_classifier_nn.h5
# Epoch 11/50000
#  - 120s - loss: 0.6148 - acc: 0.6324 - val_loss: 0.6075 - val_acc: 0.6399
#
# Epoch 00011: val_loss improved from 0.60884 to 0.60749, saving model to known_classifier_nn.h5
# Epoch 12/50000
#  - 120s - loss: 0.6129 - acc: 0.6340 - val_loss: 0.6023 - val_acc: 0.6455
#
# Epoch 00012: val_loss improved from 0.60749 to 0.60232, saving model to known_classifier_nn.h5
# Epoch 13/50000
#  - 121s - loss: 0.6104 - acc: 0.6349 - val_loss: 0.6012 - val_acc: 0.6535
#
# Epoch 00013: val_loss improved from 0.60232 to 0.60124, saving model to known_classifier_nn.h5
# Epoch 14/50000
#  - 125s - loss: 0.6089 - acc: 0.6401 - val_loss: 0.5998 - val_acc: 0.6624
#
# Epoch 00014: val_loss improved from 0.60124 to 0.59979, saving model to known_classifier_nn.h5
# Epoch 15/50000
#  - 112s - loss: 0.6068 - acc: 0.6421 - val_loss: 0.5965 - val_acc: 0.6572
#
# Epoch 00015: val_loss improved from 0.59979 to 0.59655, saving model to known_classifier_nn.h5
# Epoch 16/50000
#  - 122s - loss: 0.6048 - acc: 0.6446 - val_loss: 0.5964 - val_acc: 0.6606
#
# Epoch 00016: val_loss improved from 0.59655 to 0.59641, saving model to known_classifier_nn.h5
# Epoch 17/50000
#  - 127s - loss: 0.6036 - acc: 0.6462 - val_loss: 0.5915 - val_acc: 0.6624
#
# Epoch 00017: val_loss improved from 0.59641 to 0.59154, saving model to known_classifier_nn.h5
# Epoch 18/50000
#  - 145s - loss: 0.6019 - acc: 0.6482 - val_loss: 0.5932 - val_acc: 0.6604
#
# Epoch 00018: val_loss did not improve
# Epoch 19/50000
#  - 139s - loss: 0.5992 - acc: 0.6501 - val_loss: 0.5916 - val_acc: 0.6658
#
# Epoch 00019: val_loss did not improve
# Epoch 20/50000
#  - 136s - loss: 0.5989 - acc: 0.6495 - val_loss: 0.5909 - val_acc: 0.6647
#
# Epoch 00020: val_loss improved from 0.59154 to 0.59088, saving model to known_classifier_nn.h5
# Epoch 21/50000
#  - 139s - loss: 0.5970 - acc: 0.6527 - val_loss: 0.5928 - val_acc: 0.6673
#
# Epoch 00021: val_loss did not improve
# Epoch 22/50000
#  - 123s - loss: 0.5954 - acc: 0.6551 - val_loss: 0.5875 - val_acc: 0.6680
#
# Epoch 00022: val_loss improved from 0.59088 to 0.58752, saving model to known_classifier_nn.h5
# Epoch 23/50000
#  - 134s - loss: 0.5941 - acc: 0.6544 - val_loss: 0.5843 - val_acc: 0.6713
#
# Epoch 00023: val_loss improved from 0.58752 to 0.58434, saving model to known_classifier_nn.h5
# Epoch 24/50000
#  - 113s - loss: 0.5928 - acc: 0.6561 - val_loss: 0.5801 - val_acc: 0.6749
#
# Epoch 00024: val_loss improved from 0.58434 to 0.58013, saving model to known_classifier_nn.h5
# Epoch 25/50000
#  - 116s - loss: 0.5912 - acc: 0.6588 - val_loss: 0.5824 - val_acc: 0.6701
#
# Epoch 00025: val_loss did not improve
# Epoch 26/50000
#  - 113s - loss: 0.5896 - acc: 0.6617 - val_loss: 0.5791 - val_acc: 0.6773
#
# Epoch 00026: val_loss improved from 0.58013 to 0.57908, saving model to known_classifier_nn.h5
# Epoch 27/50000
#  - 116s - loss: 0.5889 - acc: 0.6606 - val_loss: 0.5808 - val_acc: 0.6733
#
# Epoch 00027: val_loss did not improve
# Epoch 28/50000
#  - 112s - loss: 0.5881 - acc: 0.6614 - val_loss: 0.5805 - val_acc: 0.6720
#
# Epoch 00028: val_loss did not improve
# Epoch 29/50000
#  - 116s - loss: 0.5867 - acc: 0.6637 - val_loss: 0.5778 - val_acc: 0.6748
#
# Epoch 00029: val_loss improved from 0.57908 to 0.57781, saving model to known_classifier_nn.h5
# Epoch 30/50000
#  - 115s - loss: 0.5858 - acc: 0.6642 - val_loss: 0.5736 - val_acc: 0.6757
#
# Epoch 00030: val_loss improved from 0.57781 to 0.57357, saving model to known_classifier_nn.h5
# Epoch 31/50000
#  - 116s - loss: 0.5837 - acc: 0.6672 - val_loss: 0.5739 - val_acc: 0.6842
#
# Epoch 00031: val_loss did not improve
# Epoch 32/50000
#  - 111s - loss: 0.5826 - acc: 0.6677 - val_loss: 0.5715 - val_acc: 0.6835
#
# Epoch 00032: val_loss improved from 0.57357 to 0.57151, saving model to known_classifier_nn.h5
# Epoch 33/50000
#  - 117s - loss: 0.5803 - acc: 0.6674 - val_loss: 0.5691 - val_acc: 0.6867
#
# Epoch 00033: val_loss improved from 0.57151 to 0.56906, saving model to known_classifier_nn.h5
# Epoch 34/50000
#  - 119s - loss: 0.5799 - acc: 0.6666 - val_loss: 0.5690 - val_acc: 0.6806
#
# Epoch 00034: val_loss improved from 0.56906 to 0.56903, saving model to known_classifier_nn.h5
# Epoch 35/50000
#  - 115s - loss: 0.5784 - acc: 0.6689 - val_loss: 0.5695 - val_acc: 0.6846
#
# Epoch 00035: val_loss did not improve
# Epoch 36/50000
#  - 117s - loss: 0.5784 - acc: 0.6703 - val_loss: 0.5664 - val_acc: 0.6880
#
# Epoch 00036: val_loss improved from 0.56903 to 0.56636, saving model to known_classifier_nn.h5
# Epoch 37/50000
#  - 122s - loss: 0.5758 - acc: 0.6730 - val_loss: 0.5642 - val_acc: 0.6865
#
# Epoch 00037: val_loss improved from 0.56636 to 0.56419, saving model to known_classifier_nn.h5
# Epoch 38/50000
#  - 122s - loss: 0.5738 - acc: 0.6762 - val_loss: 0.5637 - val_acc: 0.6879
#
# Epoch 00038: val_loss improved from 0.56419 to 0.56369, saving model to known_classifier_nn.h5
# Epoch 39/50000
#  - 118s - loss: 0.5743 - acc: 0.6753 - val_loss: 0.5597 - val_acc: 0.6908
#
# Epoch 00039: val_loss improved from 0.56369 to 0.55969, saving model to known_classifier_nn.h5
# Epoch 40/50000
#  - 118s - loss: 0.5721 - acc: 0.6757 - val_loss: 0.5589 - val_acc: 0.6905
#
# Epoch 00040: val_loss improved from 0.55969 to 0.55890, saving model to known_classifier_nn.h5
# Epoch 41/50000
#  - 118s - loss: 0.5710 - acc: 0.6772 - val_loss: 0.5564 - val_acc: 0.6975
#
# Epoch 00041: val_loss improved from 0.55890 to 0.55637, saving model to known_classifier_nn.h5
# Epoch 42/50000
#  - 118s - loss: 0.5696 - acc: 0.6785 - val_loss: 0.5556 - val_acc: 0.6897
#
# Epoch 00042: val_loss improved from 0.55637 to 0.55561, saving model to known_classifier_nn.h5
# Epoch 43/50000
#  - 119s - loss: 0.5696 - acc: 0.6800 - val_loss: 0.5530 - val_acc: 0.6989
#
# Epoch 00043: val_loss improved from 0.55561 to 0.55297, saving model to known_classifier_nn.h5
# Epoch 44/50000
#  - 117s - loss: 0.5682 - acc: 0.6805 - val_loss: 0.5507 - val_acc: 0.6987
#
# Epoch 00044: val_loss improved from 0.55297 to 0.55073, saving model to known_classifier_nn.h5
# Epoch 45/50000
#  - 116s - loss: 0.5673 - acc: 0.6816 - val_loss: 0.5534 - val_acc: 0.6989
#
# Epoch 00045: val_loss did not improve
# Epoch 46/50000
#  - 119s - loss: 0.5660 - acc: 0.6815 - val_loss: 0.5468 - val_acc: 0.7053
#
# Epoch 00046: val_loss improved from 0.55073 to 0.54677, saving model to known_classifier_nn.h5
# Epoch 47/50000
#  - 131s - loss: 0.5648 - acc: 0.6827 - val_loss: 0.5494 - val_acc: 0.7042
#
# Epoch 00047: val_loss did not improve
# Epoch 48/50000
#  - 125s - loss: 0.5618 - acc: 0.6859 - val_loss: 0.5414 - val_acc: 0.7062
# Epoch 00048: val_loss improved from 0.54677 to 0.54138, saving model to known_classifier_nn.h5
# Epoch 49/50000
#  - 135s - loss: 0.5623 - acc: 0.6859 - val_loss: 0.5412 - val_acc: 0.7062
#
# Epoch 00049: val_loss improved from 0.54138 to 0.54123, saving model to known_classifier_nn.h5
# Epoch 50/50000
#  - 153s - loss: 0.5611 - acc: 0.6878 - val_loss: 0.5365 - val_acc: 0.7085
#
# Epoch 00050: val_loss improved from 0.54123 to 0.53650, saving model to known_classifier_nn.h5
# Epoch 51/50000
#  - 127s - loss: 0.5584 - acc: 0.6896 - val_loss: 0.5377 - val_acc: 0.7080
#
# Epoch 00051: val_loss did not improve
# Epoch 52/50000
#  - 129s - loss: 0.5557 - acc: 0.6903 - val_loss: 0.5398 - val_acc: 0.7063
#
# Epoch 00052: val_loss did not improve
# Epoch 53/50000
#  - 127s - loss: 0.5552 - acc: 0.6909 - val_loss: 0.5357 - val_acc: 0.7058
#
# Epoch 00053: val_loss improved from 0.53650 to 0.53566, saving model to known_classifier_nn.h5
# Epoch 54/50000
#  - 127s - loss: 0.5559 - acc: 0.6911 - val_loss: 0.5331 - val_acc: 0.7102
#
# Epoch 00054: val_loss improved from 0.53566 to 0.53314, saving model to known_classifier_nn.h5
# Epoch 55/50000
#  - 131s - loss: 0.5523 - acc: 0.6950 - val_loss: 0.5346 - val_acc: 0.7118
#
# Epoch 00055: val_loss did not improve
# Epoch 56/50000
#  - 166s - loss: 0.5511 - acc: 0.6954 - val_loss: 0.5302 - val_acc: 0.7142
#
# Epoch 00056: val_loss improved from 0.53314 to 0.53017, saving model to known_classifier_nn.h5
# Epoch 57/50000
#  - 163s - loss: 0.5511 - acc: 0.6958 - val_loss: 0.5300 - val_acc: 0.7133
#
# Epoch 00057: val_loss improved from 0.53017 to 0.53000, saving model to known_classifier_nn.h5
# Epoch 58/50000
#  - 173s - loss: 0.5500 - acc: 0.6947 - val_loss: 0.5292 - val_acc: 0.7122
#
# Epoch 00058: val_loss improved from 0.53000 to 0.52924, saving model to known_classifier_nn.h5
# Epoch 59/50000
#  - 181s - loss: 0.5503 - acc: 0.6957 - val_loss: 0.5284 - val_acc: 0.7134
#
# Epoch 00059: val_loss improved from 0.52924 to 0.52845, saving model to known_classifier_nn.h5
# Epoch 60/50000
#  - 168s - loss: 0.5498 - acc: 0.6962 - val_loss: 0.5258 - val_acc: 0.7157
#
# Epoch 00060: val_loss improved from 0.52845 to 0.52575, saving model to known_classifier_nn.h5
# Epoch 61/50000
#  - 155s - loss: 0.5481 - acc: 0.6973 - val_loss: 0.5263 - val_acc: 0.7177
#  - 152s - loss: 0.5459 - acc: 0.6974 - val_loss: 0.5251 - val_acc: 0.7194
#
# Epoch 00062: val_loss improved from 0.52575 to 0.52508, saving model to known_classifier_nn.h5
# Epoch 63/50000
#  - 148s - loss: 0.5490 - acc: 0.6970 - val_loss: 0.5285 - val_acc: 0.7146
#
# Epoch 00063: val_loss did not improve
# Epoch 64/50000
#  - 178s - loss: 0.5468 - acc: 0.6987 - val_loss: 0.5256 - val_acc: 0.7178
#
# Epoch 00064: val_loss did not improve
# Epoch 65/50000
#  - 167s - loss: 0.5428 - acc: 0.7031 - val_loss: 0.5268 - val_acc: 0.7224
#
# Epoch 00065: val_loss did not improve
# Epoch 66/50000
#  - 136s - loss: 0.5431 - acc: 0.7011 - val_loss: 0.5216 - val_acc: 0.7174
#
# Epoch 00066: val_loss improved from 0.52508 to 0.52164, saving model to known_classifier_nn.h5
# Epoch 67/50000
#  - 139s - loss: 0.5425 - acc: 0.7020 - val_loss: 0.5209 - val_acc: 0.7302
#
# Epoch 00067: val_loss improved from 0.52164 to 0.52085, saving model to known_classifier_nn.h5
# Epoch 68/50000
#  - 159s - loss: 0.5423 - acc: 0.7000 - val_loss: 0.5211 - val_acc: 0.7196
#
# Epoch 00068: val_loss did not improve
# Epoch 69/50000
#  - 151s - loss: 0.5417 - acc: 0.7041 - val_loss: 0.5202 - val_acc: 0.7207
#
# Epoch 00069: val_loss improved from 0.52085 to 0.52021, saving model to known_classifier_nn.h5
# Epoch 70/50000
#  - 159s - loss: 0.5403 - acc: 0.7043 - val_loss: 0.5244 - val_acc: 0.7303
#
# Epoch 00070: val_loss did not improve
# Epoch 71/50000
#  - 167s - loss: 0.5399 - acc: 0.7056 - val_loss: 0.5207 - val_acc: 0.7222
#
# Epoch 00071: val_loss did not improve
# Epoch 72/50000
#  - 154s - loss: 0.5388 - acc: 0.7046 - val_loss: 0.5207 - val_acc: 0.7290
#
# Epoch 00072: val_loss did not improve
# Epoch 73/50000
#  - 170s - loss: 0.5403 - acc: 0.7057 - val_loss: 0.5208 - val_acc: 0.7297
#
# Epoch 00073: val_loss did not improve
# Epoch 74/50000
#  - 177s - loss: 0.5396 - acc: 0.7048 - val_loss: 0.5190 - val_acc: 0.7334
#
# Epoch 00074: val_loss improved from 0.52021 to 0.51905, saving model to known_classifier_nn.h5
# Epoch 75/50000
#  - 143s - loss: 0.5381 - acc: 0.7056 - val_loss: 0.5153 - val_acc: 0.7277
#
# Epoch 00075: val_loss improved from 0.51905 to 0.51533, saving model to known_classifier_nn.h5
# Epoch 76/50000
#  - 143s - loss: 0.5349 - acc: 0.7077 - val_loss: 0.5142 - val_acc: 0.7357
#
# Epoch 00076: val_loss improved from 0.51533 to 0.51416, saving model to known_classifier_nn.h5
# Epoch 77/50000
#  - 157s - loss: 0.5368 - acc: 0.7054 - val_loss: 0.5124 - val_acc: 0.7329
#
# Epoch 00077: val_loss improved from 0.51416 to 0.51242, saving model to known_classifier_nn.h5
# Epoch 78/50000
#  - 130s - loss: 0.5363 - acc: 0.7070 - val_loss: 0.5144 - val_acc: 0.7263
#
# Epoch 00078: val_loss did not improve
# Epoch 79/50000
#  - 141s - loss: 0.5359 - acc: 0.7073 - val_loss: 0.5139 - val_acc: 0.7310
#
# Epoch 00079: val_loss did not improve
# Epoch 80/50000
#  - 154s - loss: 0.5350 - acc: 0.7079 - val_loss: 0.5097 - val_acc: 0.7301
#
# Epoch 00080: val_loss improved from 0.51242 to 0.50975, saving model to known_classifier_nn.h5
# Epoch 81/50000
#  - 189s - loss: 0.5347 - acc: 0.7075 - val_loss: 0.5105 - val_acc: 0.7303
#
# Epoch 00081: val_loss did not improve
# Epoch 82/50000
#  - 180s - loss: 0.5338 - acc: 0.7086 - val_loss: 0.5112 - val_acc: 0.7358
#
# Epoch 00082: val_loss did not improve
# Epoch 83/50000
#  - 148s - loss: 0.5345 - acc: 0.7108 - val_loss: 0.5082 - val_acc: 0.7294
#
# Epoch 00083: val_loss improved from 0.50975 to 0.50819, saving model to known_classifier_nn.h5
# Epoch 84/50000
#  - 161s - loss: 0.5403 - acc: 0.7028 - val_loss: 0.5230 - val_acc: 0.7285
#
# Epoch 00084: val_loss did not improve
# Epoch 85/50000
#  - 165s - loss: 0.5356 - acc: 0.7073 - val_loss: 0.5111 - val_acc: 0.7332
#
# Epoch 00085: val_loss did not improve
# Epoch 86/50000
#  - 172s - loss: 0.5306 - acc: 0.7116 - val_loss: 0.5099 - val_acc: 0.7278
#
# Epoch 00086: val_loss did not improve
# Epoch 87/50000
#  - 168s - loss: 0.5299 - acc: 0.7123 - val_loss: 0.5056 - val_acc: 0.7372
#
# Epoch 00087: val_loss improved from 0.50819 to 0.50560, saving model to known_classifier_nn.h5
# Epoch 88/50000
#  - 157s - loss: 0.5329 - acc: 0.7095 - val_loss: 0.5092 - val_acc: 0.7326
#
# Epoch 00088: val_loss did not improve
# Epoch 89/50000
#  - 147s - loss: 0.5308 - acc: 0.7122 - val_loss: 0.5060 - val_acc: 0.7326
#
# Epoch 00089: val_loss did not improve
# Epoch 90/50000
#  - 145s - loss: 0.5315 - acc: 0.7109 - val_loss: 0.5060 - val_acc: 0.7342
#
# Epoch 00090: val_loss did not improve
# Epoch 91/50000
#  - 136s - loss: 0.5305 - acc: 0.7110 - val_loss: 0.5093 - val_acc: 0.7339
#
# Epoch 00091: val_loss did not improve
# Epoch 92/50000
#  - 150s - loss: 0.5315 - acc: 0.7101 - val_loss: 0.5039 - val_acc: 0.7380
#
# Epoch 00092: val_loss improved from 0.50560 to 0.50393, saving model to known_classifier_nn.h5
# Epoch 93/50000
#  - 158s - loss: 0.5293 - acc: 0.7119 - val_loss: 0.5223 - val_acc: 0.7204
#
# Epoch 00093: val_loss did not improve
# Epoch 94/50000
#  - 175s - loss: 0.5298 - acc: 0.7148 - val_loss: 0.5044 - val_acc: 0.7351
#
# Epoch 00094: val_loss did not improve
# Epoch 95/50000
#  - 168s - loss: 0.5282 - acc: 0.7131 - val_loss: 0.5060 - val_acc: 0.7306
#
# Epoch 00095: val_loss did not improve
# Epoch 96/50000
#  - 171s - loss: 0.5297 - acc: 0.7093 - val_loss: 0.5045 - val_acc: 0.7365
#
# Epoch 00096: val_loss did not improve
# Epoch 97/50000
#  - 171s - loss: 0.5301 - acc: 0.7111 - val_loss: 0.5052 - val_acc: 0.7383
#
# Epoch 00097: val_loss did not improve
# Epoch 98/50000
#  - 167s - loss: 0.5266 - acc: 0.7145 - val_loss: 0.5030 - val_acc: 0.7383
#
# Epoch 00098: val_loss improved from 0.50393 to 0.50297, saving model to known_classifier_nn.h5
# Epoch 99/50000
#  - 166s - loss: 0.5255 - acc: 0.7150 - val_loss: 0.5050 - val_acc: 0.7320
#
# Epoch 00099: val_loss did not improve
# Epoch 100/50000
#  - 139s - loss: 0.5239 - acc: 0.7153 - val_loss: 0.4983 - val_acc: 0.7399
#
# Epoch 00100: val_loss improved from 0.50297 to 0.49825, saving model to known_classifier_nn.h5
# Epoch 101/50000
#  - 152s - loss: 0.5261 - acc: 0.7144 - val_loss: 0.5011 - val_acc: 0.7413
#
# Epoch 00101: val_loss did not improve
# Epoch 102/50000
#  - 150s - loss: 0.5247 - acc: 0.7162 - val_loss: 0.5042 - val_acc: 0.7331
# Epoch 00102: val_loss did not improve
# Epoch 103/50000
#  - 128s - loss: 0.5264 - acc: 0.7153 - val_loss: 0.5052 - val_acc: 0.7336
#
# Epoch 00103: val_loss did not improve
# Epoch 104/50000
#  - 150s - loss: 0.5265 - acc: 0.7159 - val_loss: 0.5007 - val_acc: 0.7375
#
# Epoch 00104: val_loss did not improve
# Epoch 105/50000
#  - 137s - loss: 0.5237 - acc: 0.7167 - val_loss: 0.5009 - val_acc: 0.7356
#
# Epoch 00105: val_loss did not improve
# Epoch 106/50000
#  - 145s - loss: 0.5243 - acc: 0.7182 - val_loss: 0.4994 - val_acc: 0.7382
#
# Epoch 00106: val_loss did not improve
# Epoch 107/50000
#  - 145s - loss: 0.5230 - acc: 0.7178 - val_loss: 0.4971 - val_acc: 0.7427
#
# Epoch 00107: val_loss improved from 0.49825 to 0.49713, saving model to known_classifier_nn.h5
# Epoch 108/50000
#  - 154s - loss: 0.5218 - acc: 0.7182 - val_loss: 0.4969 - val_acc: 0.7379
#
# Epoch 00108: val_loss improved from 0.49713 to 0.49689, saving model to known_classifier_nn.h5
# Epoch 109/50000
#  - 157s - loss: 0.5239 - acc: 0.7175 - val_loss: 0.4974 - val_acc: 0.7348
#
# Epoch 00109: val_loss did not improve
# Epoch 110/50000
#  - 140s - loss: 0.5234 - acc: 0.7183 - val_loss: 0.4968 - val_acc: 0.7407
#
# Epoch 00110: val_loss improved from 0.49689 to 0.49685, saving model to known_classifier_nn.h5
# Epoch 111/50000
#  - 133s - loss: 0.5240 - acc: 0.7169 - val_loss: 0.5014 - val_acc: 0.7359
#
# Epoch 00111: val_loss did not improve
# Epoch 112/50000
#  - 135s - loss: 0.5232 - acc: 0.7170 - val_loss: 0.4939 - val_acc: 0.7414
#
# Epoch 00112: val_loss improved from 0.49685 to 0.49389, saving model to known_classifier_nn.h5
# Epoch 113/50000
#  - 151s - loss: 0.5234 - acc: 0.7184 - val_loss: 0.4949 - val_acc: 0.7455
#
# Epoch 00113: val_loss did not improve
# Epoch 114/50000
#  - 153s - loss: 0.5200 - acc: 0.7197 - val_loss: 0.4960 - val_acc: 0.7392
#
# Epoch 00114: val_loss did not improve
# Epoch 115/50000
#  - 136s - loss: 0.5245 - acc: 0.7154 - val_loss: 0.5077 - val_acc: 0.7289
#
# Epoch 00115: val_loss did not improve
# Epoch 116/50000
#  - 129s - loss: 0.5220 - acc: 0.7177 - val_loss: 0.4971 - val_acc: 0.7402
#
# Epoch 00116: val_loss did not improve
# Epoch 117/50000
#  - 148s - loss: 0.5202 - acc: 0.7179 - val_loss: 0.4976 - val_acc: 0.7412
#
# Epoch 00117: val_loss did not improve
# Epoch 118/50000
#  - 168s - loss: 0.5225 - acc: 0.7157 - val_loss: 0.4973 - val_acc: 0.7409
#
# Epoch 00118: val_loss did not improve
# Epoch 119/50000
#  - 161s - loss: 0.5215 - acc: 0.7185 - val_loss: 0.4940 - val_acc: 0.7418
#
# Epoch 00119: val_loss did not improve
# Epoch 120/50000
#  - 133s - loss: 0.5197 - acc: 0.7200 - val_loss: 0.4973 - val_acc: 0.7435
#
# Epoch 00120: val_loss did not improve
# Epoch 121/50000
#  - 147s - loss: 0.5205 - acc: 0.7192 - val_loss: 0.4983 - val_acc: 0.7387
#
# Epoch 00121: val_loss did not improve
# Epoch 122/50000
#  - 144s - loss: 0.5214 - acc: 0.7199 - val_loss: 0.5010 - val_acc: 0.7356
#
# Epoch 00122: val_loss did not improve
# Epoch 123/50000
#  - 156s - loss: 0.5185 - acc: 0.7208 - val_loss: 0.4962 - val_acc: 0.7433
#
# Epoch 00123: val_loss did not improve
# Epoch 124/50000
#  - 163s - loss: 0.5173 - acc: 0.7229 - val_loss: 0.4959 - val_acc: 0.7422
#
# Epoch 00124: val_loss did not improve
# Epoch 125/50000
#  - 152s - loss: 0.5183 - acc: 0.7226 - val_loss: 0.4890 - val_acc: 0.7453
#
# Epoch 00125: val_loss improved from 0.49389 to 0.48902, saving model to known_classifier_nn.h5
# Epoch 126/50000
#  - 158s - loss: 0.5173 - acc: 0.7240 - val_loss: 0.4917 - val_acc: 0.7447
#
# Epoch 00126: val_loss did not improve
# Epoch 127/50000
#  - 136s - loss: 0.5175 - acc: 0.7187 - val_loss: 0.4943 - val_acc: 0.7381
#
# Epoch 00127: val_loss did not improve
# Epoch 128/50000
#  - 154s - loss: 0.5183 - acc: 0.7215 - val_loss: 0.4922 - val_acc: 0.7441
#
# Epoch 00128: val_loss did not improve
# Epoch 129/50000
#  - 138s - loss: 0.5183 - acc: 0.7208 - val_loss: 0.4875 - val_acc: 0.7432
#
# Epoch 00129: val_loss improved from 0.48902 to 0.48752, saving model to known_classifier_nn.h5
# Epoch 130/50000
#  - 146s - loss: 0.5172 - acc: 0.7205 - val_loss: 0.4883 - val_acc: 0.7452
#
# Epoch 00130: val_loss did not improve
# Epoch 131/50000
#  - 127s - loss: 0.5176 - acc: 0.7215 - val_loss: 0.4898 - val_acc: 0.7442
#
# Epoch 00131: val_loss did not improve
# Epoch 132/50000
#  - 120s - loss: 0.5178 - acc: 0.7222 - val_loss: 0.4925 - val_acc: 0.7412
#
# Epoch 00132: val_loss did not improve
# Epoch 133/50000
#  - 135s - loss: 0.5160 - acc: 0.7242 - val_loss: 0.4876 - val_acc: 0.7432
#
# Epoch 00133: val_loss did not improve
# Epoch 134/50000
#  - 121s - loss: 0.5167 - acc: 0.7214 - val_loss: 0.4921 - val_acc: 0.7419
#
# Epoch 00134: val_loss did not improve
# Epoch 135/50000
#  - 151s - loss: 0.5151 - acc: 0.7243 - val_loss: 0.4889 - val_acc: 0.7484
#
# Epoch 00135: val_loss did not improve
# Epoch 136/50000
#  - 144s - loss: 0.5170 - acc: 0.7221 - val_loss: 0.4879 - val_acc: 0.7481
#
# Epoch 00136: val_loss did not improve
# Epoch 137/50000
#  - 137s - loss: 0.5127 - acc: 0.7245 - val_loss: 0.4859 - val_acc: 0.7470
#
# Epoch 00137: val_loss improved from 0.48752 to 0.48587, saving model to known_classifier_nn.h5
# Epoch 138/50000
#  - 144s - loss: 0.5128 - acc: 0.7253 - val_loss: 0.4922 - val_acc: 0.7431
#
# Epoch 00138: val_loss did not improve
# Epoch 139/50000
#  - 137s - loss: 0.5135 - acc: 0.7253 - val_loss: 0.4895 - val_acc: 0.7438
#
# Epoch 00139: val_loss did not improve
# Epoch 140/50000
#  - 124s - loss: 0.5147 - acc: 0.7233 - val_loss: 0.4897 - val_acc: 0.7440
#
# Epoch 00140: val_loss did not improve
# Epoch 141/50000
#  - 133s - loss: 0.5214 - acc: 0.7191 - val_loss: 0.4980 - val_acc: 0.7423
#
# Epoch 00141: val_loss did not improve
# Epoch 142/50000
#  - 138s - loss: 0.5225 - acc: 0.7182 - val_loss: 0.4931 - val_acc: 0.7420
#
# Epoch 00142: val_loss did not improve
# Epoch 143/50000
#  - 147s - loss: 0.5219 - acc: 0.7177 - val_loss: 0.4951 - val_acc: 0.7447
#
# Epoch 00143: val_loss did not improve
# Epoch 144/50000
#  - 142s - loss: 0.5190 - acc: 0.7200 - val_loss: 0.4860 - val_acc: 0.7472
#
# Epoch 00144: val_loss did not improve
# Epoch 145/50000
#  - 144s - loss: 0.5239 - acc: 0.7177 - val_loss: 0.4950 - val_acc: 0.7428
#
# Epoch 00145: val_loss did not improve
# Epoch 146/50000
#  - 146s - loss: 0.5187 - acc: 0.7199 - val_loss: 0.4912 - val_acc: 0.7446
#
# Epoch 00146: val_loss did not improve
# Epoch 147/50000
#  - 148s - loss: 0.5206 - acc: 0.7197 - val_loss: 0.4842 - val_acc: 0.7480
#
# Epoch 00147: val_loss improved from 0.48587 to 0.48423, saving model to known_classifier_nn.h5
# Epoch 148/50000
#  - 134s - loss: 0.5188 - acc: 0.7208 - val_loss: 0.4897 - val_acc: 0.7472
#
# Epoch 00148: val_loss did not improve
# Epoch 149/50000
#  - 117s - loss: 0.5199 - acc: 0.7205 - val_loss: 0.4874 - val_acc: 0.7471
#
# Epoch 00149: val_loss did not improve
# Epoch 150/50000
#  - 117s - loss: 0.5206 - acc: 0.7185 - val_loss: 0.4954 - val_acc: 0.7394
#
# Epoch 00150: val_loss did not improve
# Epoch 151/50000
#  - 112s - loss: 0.5195 - acc: 0.7210 - val_loss: 0.4855 - val_acc: 0.7469
#
# Epoch 00151: val_loss did not improve
# Epoch 152/50000
#  - 114s - loss: 0.5210 - acc: 0.7190 - val_loss: 0.4895 - val_acc: 0.7487
#
# Epoch 00152: val_loss did not improve
# Epoch 153/50000
#  - 114s - loss: 0.5185 - acc: 0.7214 - val_loss: 0.4850 - val_acc: 0.7474
#
# Epoch 00153: val_loss did not improve
# Epoch 154/50000
#  - 126s - loss: 0.5193 - acc: 0.7214 - val_loss: 0.4908 - val_acc: 0.7485
#
# Epoch 00154: val_loss did not improve
# Epoch 155/50000
#  - 129s - loss: 0.5190 - acc: 0.7195 - val_loss: 0.4892 - val_acc: 0.7448
#
# Epoch 00155: val_loss did not improve
# Epoch 156/50000
#  - 140s - loss: 0.5184 - acc: 0.7210 - val_loss: 0.4925 - val_acc: 0.7424
#
# Epoch 00156: val_loss did not improve
# Epoch 157/50000
#  - 143s - loss: 0.5205 - acc: 0.7183 - val_loss: 0.4872 - val_acc: 0.7505
#
# Epoch 00157: val_loss did not improve
# Epoch 158/50000
#  - 157s - loss: 0.5167 - acc: 0.7223 - val_loss: 0.4907 - val_acc: 0.7464
#
# Epoch 00158: val_loss did not improve
# Epoch 159/50000
#  - 131s - loss: 0.5189 - acc: 0.7202 - val_loss: 0.4933 - val_acc: 0.7451
#
# Epoch 00159: val_loss did not improve
# Epoch 160/50000
#  - 127s - loss: 0.5181 - acc: 0.7209 - val_loss: 0.4872 - val_acc: 0.7501
#
# Epoch 00160: val_loss did not improve
# Epoch 161/50000
#  - 137s - loss: 0.5155 - acc: 0.7230 - val_loss: 0.4823 - val_acc: 0.7504
#
# Epoch 00161: val_loss improved from 0.48423 to 0.48225, saving model to known_classifier_nn.h5
# Epoch 162/50000
#  - 131s - loss: 0.5155 - acc: 0.7238 - val_loss: 0.4828 - val_acc: 0.7499
# Epoch 00162: val_loss did not improve
# Epoch 163/50000
#  - 128s - loss: 0.5170 - acc: 0.7219 - val_loss: 0.4847 - val_acc: 0.7482
#
# Epoch 00163: val_loss did not improve
# Epoch 164/50000
#  - 121s - loss: 0.5176 - acc: 0.7200 - val_loss: 0.4923 - val_acc: 0.7460
#
# Epoch 00164: val_loss did not improve
# Epoch 165/50000
#  - 120s - loss: 0.5182 - acc: 0.7200 - val_loss: 0.4833 - val_acc: 0.7489
#
# Epoch 00165: val_loss did not improve
# Epoch 166/50000
#  - 130s - loss: 0.5181 - acc: 0.7199 - val_loss: 0.4860 - val_acc: 0.7476
#
# Epoch 00166: val_loss did not improve
# Epoch 167/50000
#  - 114s - loss: 0.5184 - acc: 0.7227 - val_loss: 0.4813 - val_acc: 0.7527
#
# Epoch 00167: val_loss improved from 0.48225 to 0.48133, saving model to known_classifier_nn.h5
# Epoch 168/50000
#  - 116s - loss: 0.5172 - acc: 0.7215 - val_loss: 0.4822 - val_acc: 0.7494
#
# Epoch 00168: val_loss did not improve
# Epoch 169/50000
#  - 113s - loss: 0.5098 - acc: 0.7252 - val_loss: 0.4794 - val_acc: 0.7484
#
# Epoch 00169: val_loss improved from 0.48133 to 0.47939, saving model to known_classifier_nn.h5
# Epoch 170/50000
#  - 119s - loss: 0.5119 - acc: 0.7251 - val_loss: 0.4802 - val_acc: 0.7506
#
# Epoch 00170: val_loss did not improve
# Epoch 171/50000
#  - 111s - loss: 0.5126 - acc: 0.7261 - val_loss: 0.4803 - val_acc: 0.7506
#
# Epoch 00171: val_loss did not improve
# Epoch 172/50000
#  - 113s - loss: 0.5097 - acc: 0.7262 - val_loss: 0.4945 - val_acc: 0.7388
#
# Epoch 00172: val_loss did not improve
# Epoch 173/50000
#  - 115s - loss: 0.5107 - acc: 0.7272 - val_loss: 0.4792 - val_acc: 0.7493
#
# Epoch 00173: val_loss improved from 0.47939 to 0.47919, saving model to known_classifier_nn.h5
# Epoch 174/50000
#  - 115s - loss: 0.5112 - acc: 0.7271 - val_loss: 0.4809 - val_acc: 0.7492
#
# Epoch 00174: val_loss did not improve
# Epoch 175/50000
#  - 113s - loss: 0.5120 - acc: 0.7245 - val_loss: 0.4813 - val_acc: 0.7485
#
# Epoch 00175: val_loss did not improve
# Epoch 176/50000
#  - 118s - loss: 0.5104 - acc: 0.7263 - val_loss: 0.4874 - val_acc: 0.7518
#
# Epoch 00176: val_loss did not improve
# Epoch 177/50000
#  - 113s - loss: 0.5097 - acc: 0.7264 - val_loss: 0.4780 - val_acc: 0.7515
#
# Epoch 00177: val_loss improved from 0.47919 to 0.47799, saving model to known_classifier_nn.h5
# Epoch 178/50000
#  - 115s - loss: 0.5138 - acc: 0.7257 - val_loss: 0.4859 - val_acc: 0.7439
#
# Epoch 00178: val_loss did not improve
# Epoch 179/50000
#  - 112s - loss: 0.5113 - acc: 0.7270 - val_loss: 0.4812 - val_acc: 0.7488
#
# Epoch 00179: val_loss did not improve
# Epoch 180/50000
#  - 115s - loss: 0.5084 - acc: 0.7269 - val_loss: 0.4790 - val_acc: 0.7507
#
# Epoch 00180: val_loss did not improve
# Epoch 181/50000
#  - 116s - loss: 0.5082 - acc: 0.7297 - val_loss: 0.4777 - val_acc: 0.7538
#
# Epoch 00181: val_loss improved from 0.47799 to 0.47768, saving model to known_classifier_nn.h5
# Epoch 182/50000
#  - 114s - loss: 0.5086 - acc: 0.7279 - val_loss: 0.4806 - val_acc: 0.7481
#
# Epoch 00182: val_loss did not improve
# Epoch 183/50000
#  - 114s - loss: 0.5094 - acc: 0.7277 - val_loss: 0.4770 - val_acc: 0.7530
#
# Epoch 00183: val_loss improved from 0.47768 to 0.47698, saving model to known_classifier_nn.h5
# Epoch 184/50000
#  - 113s - loss: 0.5094 - acc: 0.7267 - val_loss: 0.4852 - val_acc: 0.7443
#
# Epoch 00184: val_loss did not improve
# Epoch 185/50000
#  - 116s - loss: 0.5092 - acc: 0.7261 - val_loss: 0.4764 - val_acc: 0.7512
#
# Epoch 00185: val_loss improved from 0.47698 to 0.47645, saving model to known_classifier_nn.h5
# Epoch 186/50000
#  - 113s - loss: 0.5084 - acc: 0.7287 - val_loss: 0.4801 - val_acc: 0.7508
#
# Epoch 00186: val_loss did not improve
# Epoch 187/50000
#  - 116s - loss: 0.5093 - acc: 0.7269 - val_loss: 0.4745 - val_acc: 0.7495
#
# Epoch 00187: val_loss improved from 0.47645 to 0.47446, saving model to known_classifier_nn.h5
# Epoch 188/50000
#  - 116s - loss: 0.5088 - acc: 0.7271 - val_loss: 0.4872 - val_acc: 0.7469
#
# Epoch 00188: val_loss did not improve
# Epoch 189/50000
#  - 115s - loss: 0.5062 - acc: 0.7280 - val_loss: 0.4783 - val_acc: 0.7527
#
# Epoch 00189: val_loss did not improve
# Epoch 190/50000
#  - 113s - loss: 0.5062 - acc: 0.7286 - val_loss: 0.4770 - val_acc: 0.7521
#
# Epoch 00190: val_loss did not improve
# Epoch 191/50000
#  - 116s - loss: 0.5072 - acc: 0.7270 - val_loss: 0.4795 - val_acc: 0.7485
#
# Epoch 00191: val_loss did not improve
# Epoch 192/50000
#  - 113s - loss: 0.5092 - acc: 0.7282 - val_loss: 0.4757 - val_acc: 0.7521
#
# Epoch 00192: val_loss did not improve
# Epoch 193/50000
#  - 114s - loss: 0.5108 - acc: 0.7250 - val_loss: 0.4867 - val_acc: 0.7438
#
# Epoch 00193: val_loss did not improve
# Epoch 194/50000
#  - 115s - loss: 0.5129 - acc: 0.7251 - val_loss: 0.4762 - val_acc: 0.7544
#
# Epoch 00194: val_loss did not improve
# Epoch 195/50000
#  - 114s - loss: 0.5119 - acc: 0.7249 - val_loss: 0.4787 - val_acc: 0.7499
#
# Epoch 00195: val_loss did not improve
# Epoch 196/50000
#  - 120s - loss: 0.5129 - acc: 0.7240 - val_loss: 0.4840 - val_acc: 0.7476
#
# Epoch 00196: val_loss did not improve
# Epoch 197/50000
#  - 112s - loss: 0.5109 - acc: 0.7242 - val_loss: 0.4814 - val_acc: 0.7531
#
# Epoch 00197: val_loss did not improve
# Epoch 198/50000
#  - 114s - loss: 0.5139 - acc: 0.7247 - val_loss: 0.4800 - val_acc: 0.7551
#
# Epoch 00198: val_loss did not improve
# Epoch 199/50000
#  - 115s - loss: 0.5122 - acc: 0.7244 - val_loss: 0.4795 - val_acc: 0.7513
#
# Epoch 00199: val_loss did not improve
# Epoch 200/50000
#  - 118s - loss: 0.5094 - acc: 0.7265 - val_loss: 0.4779 - val_acc: 0.7534
#
# Epoch 00200: val_loss did not improve
# Epoch 201/50000
#  - 114s - loss: 0.5111 - acc: 0.7278 - val_loss: 0.4782 - val_acc: 0.7556
#
# Epoch 00201: val_loss did not improve
# Epoch 202/50000
#  - 114s - loss: 0.5055 - acc: 0.7308 - val_loss: 0.4808 - val_acc: 0.7477
#
# Epoch 00202: val_loss did not improve
# Epoch 203/50000
#  - 115s - loss: 0.5088 - acc: 0.7277 - val_loss: 0.4772 - val_acc: 0.7535
#
# Epoch 00203: val_loss did not improve
# Epoch 204/50000
#  - 113s - loss: 0.5078 - acc: 0.7281 - val_loss: 0.4734 - val_acc: 0.7541
#
# Epoch 00204: val_loss improved from 0.47446 to 0.47342, saving model to known_classifier_nn.h5
# Epoch 205/50000
#  - 119s - loss: 0.5070 - acc: 0.7292 - val_loss: 0.4733 - val_acc: 0.7559
#
# Epoch 00205: val_loss improved from 0.47342 to 0.47330, saving model to known_classifier_nn.h5
# Epoch 206/50000
#  - 114s - loss: 0.5059 - acc: 0.7299 - val_loss: 0.4756 - val_acc: 0.7553
#
# Epoch 00206: val_loss did not improve
# Epoch 207/50000
#  - 114s - loss: 0.5065 - acc: 0.7295 - val_loss: 0.4757 - val_acc: 0.7539
#
# Epoch 00207: val_loss did not improve
# Epoch 208/50000
#  - 115s - loss: 0.5078 - acc: 0.7284 - val_loss: 0.4752 - val_acc: 0.7516
#
# Epoch 00208: val_loss did not improve
# Epoch 209/50000
#  - 115s - loss: 0.5087 - acc: 0.7278 - val_loss: 0.4761 - val_acc: 0.7563
#
# Epoch 00209: val_loss did not improve
# Epoch 210/50000
#  - 111s - loss: 0.5058 - acc: 0.7294 - val_loss: 0.4763 - val_acc: 0.7565
#
# Epoch 00210: val_loss did not improve
# Epoch 211/50000
#  - 114s - loss: 0.5047 - acc: 0.7312 - val_loss: 0.4734 - val_acc: 0.7575
#
# Epoch 00211: val_loss did not improve
# Epoch 212/50000
#  - 113s - loss: 0.5037 - acc: 0.7325 - val_loss: 0.4708 - val_acc: 0.7578
#
# Epoch 00212: val_loss improved from 0.47330 to 0.47076, saving model to known_classifier_nn.h5
# Epoch 213/50000
#  - 113s - loss: 0.5064 - acc: 0.7300 - val_loss: 0.4752 - val_acc: 0.7525
#
# Epoch 00213: val_loss did not improve
# Epoch 214/50000
#  - 116s - loss: 0.5053 - acc: 0.7296 - val_loss: 0.4798 - val_acc: 0.7499
#
# Epoch 00214: val_loss did not improve
# Epoch 215/50000
#  - 114s - loss: 0.5044 - acc: 0.7308 - val_loss: 0.4701 - val_acc: 0.7542
#
# Epoch 00215: val_loss improved from 0.47076 to 0.47006, saving model to known_classifier_nn.h5
# Epoch 216/50000
#  - 112s - loss: 0.5062 - acc: 0.7295 - val_loss: 0.4731 - val_acc: 0.7561
#
# Epoch 00216: val_loss did not improve
# Epoch 217/50000
#  - 111s - loss: 0.5050 - acc: 0.7320 - val_loss: 0.4747 - val_acc: 0.7532
#
# Epoch 00217: val_loss did not improve
# Epoch 218/50000
#  - 114s - loss: 0.5075 - acc: 0.7275 - val_loss: 0.4712 - val_acc: 0.7531
#
# Epoch 00218: val_loss did not improve
# Epoch 219/50000
#  - 112s - loss: 0.5048 - acc: 0.7309 - val_loss: 0.4720 - val_acc: 0.7549
#
# Epoch 00219: val_loss did not improve
# Epoch 220/50000
#  - 114s - loss: 0.5071 - acc: 0.7306 - val_loss: 0.4729 - val_acc: 0.7585
#
# Epoch 00220: val_loss did not improve
# Epoch 221/50000
#  - 114s - loss: 0.5032 - acc: 0.7308 - val_loss: 0.4727 - val_acc: 0.7549
#
# Epoch 00221: val_loss did not improve
# Epoch 222/50000
#  - 116s - loss: 0.5050 - acc: 0.7307 - val_loss: 0.4759 - val_acc: 0.7503
#
# Epoch 00222: val_loss did not improve
# Epoch 223/50000
#  - 113s - loss: 0.5059 - acc: 0.7297 - val_loss: 0.4738 - val_acc: 0.7542
#
# Epoch 00223: val_loss did not improve
# Epoch 224/50000
#  - 113s - loss: 0.5115 - acc: 0.7249 - val_loss: 0.4798 - val_acc: 0.7554
#
# Epoch 00224: val_loss did not improve
# Epoch 225/50000
#  - 114s - loss: 0.5146 - acc: 0.7219 - val_loss: 0.4771 - val_acc: 0.7558
#
# Epoch 00225: val_loss did not improve
# Epoch 226/50000
#  - 114s - loss: 0.5123 - acc: 0.7264 - val_loss: 0.4781 - val_acc: 0.7542
#
# Epoch 00226: val_loss did not improve
# Epoch 227/50000
#  - 114s - loss: 0.5091 - acc: 0.7278 - val_loss: 0.4795 - val_acc: 0.7539
#
# Epoch 00227: val_loss did not improve
# Epoch 228/50000
#  - 114s - loss: 0.5094 - acc: 0.7271 - val_loss: 0.4804 - val_acc: 0.7533
#
# Epoch 00228: val_loss did not improve
# Epoch 229/50000
#  - 114s - loss: 0.5088 - acc: 0.7297 - val_loss: 0.4726 - val_acc: 0.7551
#
# Epoch 00229: val_loss did not improve
# Epoch 230/50000
#  - 113s - loss: 0.5092 - acc: 0.7283 - val_loss: 0.4723 - val_acc: 0.7558
#
# Epoch 00230: val_loss did not improve
# Epoch 231/50000
#  - 113s - loss: 0.5059 - acc: 0.7313 - val_loss: 0.4763 - val_acc: 0.7514
#
# Epoch 00231: val_loss did not improve
# Epoch 232/50000
#  - 114s - loss: 0.5058 - acc: 0.7300 - val_loss: 0.4786 - val_acc: 0.7544
#
# Epoch 00232: val_loss did not improve
# Epoch 233/50000
#  - 116s - loss: 0.5040 - acc: 0.7309 - val_loss: 0.4782 - val_acc: 0.7502
#
# Epoch 00233: val_loss did not improve
# Epoch 234/50000
#  - 114s - loss: 0.5020 - acc: 0.7327 - val_loss: 0.4737 - val_acc: 0.7546
#
# Epoch 00234: val_loss did not improve
# Epoch 235/50000
#  - 117s - loss: 0.5040 - acc: 0.7322 - val_loss: 0.4742 - val_acc: 0.7555
#
# Epoch 00235: val_loss did not improve
# Epoch 236/50000
#  - 118s - loss: 0.5060 - acc: 0.7306 - val_loss: 0.4788 - val_acc: 0.7502
#
# Epoch 00236: val_loss did not improve
# Epoch 237/50000
#  - 115s - loss: 0.5071 - acc: 0.7277 - val_loss: 0.4756 - val_acc: 0.7529
#
# Epoch 00237: val_loss did not improve
# Epoch 238/50000
#  - 115s - loss: 0.5057 - acc: 0.7299 - val_loss: 0.4732 - val_acc: 0.7562
#
# Epoch 00238: val_loss did not improve
# Epoch 239/50000
#  - 116s - loss: 0.5091 - acc: 0.7273 - val_loss: 0.4763 - val_acc: 0.7562
#
# Epoch 00239: val_loss did not improve
# Epoch 240/50000
#  - 115s - loss: 0.5111 - acc: 0.7259 - val_loss: 0.4739 - val_acc: 0.7576
#
# Epoch 00240: val_loss did not improve
# Epoch 241/50000
#  - 116s - loss: 0.5044 - acc: 0.7309 - val_loss: 0.4712 - val_acc: 0.7540
#
# Epoch 00241: val_loss did not improve
# Epoch 242/50000
#  - 115s - loss: 0.5049 - acc: 0.7308 - val_loss: 0.4700 - val_acc: 0.7560
#
# Epoch 00242: val_loss improved from 0.47006 to 0.46999, saving model to known_classifier_nn.h5
# Epoch 243/50000
#  - 115s - loss: 0.5043 - acc: 0.7304 - val_loss: 0.4771 - val_acc: 0.7558
#
# Epoch 00243: val_loss did not improve
# Epoch 244/50000
#  - 112s - loss: 0.5050 - acc: 0.7302 - val_loss: 0.4817 - val_acc: 0.7498
#
# Epoch 00244: val_loss did not improve
# Epoch 245/50000
#  - 116s - loss: 0.5043 - acc: 0.7297 - val_loss: 0.4724 - val_acc: 0.7555
#
# Epoch 00245: val_loss did not improve
# Epoch 246/50000
#  - 115s - loss: 0.5051 - acc: 0.7314 - val_loss: 0.4736 - val_acc: 0.7554
#
# Epoch 00246: val_loss did not improve
# Epoch 247/50000
#  - 118s - loss: 0.5037 - acc: 0.7306 - val_loss: 0.4693 - val_acc: 0.7600
#
# Epoch 00247: val_loss improved from 0.46999 to 0.46926, saving model to known_classifier_nn.h5
# Epoch 248/50000
#  - 118s - loss: 0.5021 - acc: 0.7313 - val_loss: 0.4682 - val_acc: 0.7589
#
# Epoch 00248: val_loss improved from 0.46926 to 0.46815, saving model to known_classifier_nn.h5
# Epoch 249/50000
#  - 112s - loss: 0.5045 - acc: 0.7312 - val_loss: 0.4717 - val_acc: 0.7565
#
# Epoch 00249: val_loss did not improve
# Epoch 250/50000
#  - 115s - loss: 0.5007 - acc: 0.7347 - val_loss: 0.4678 - val_acc: 0.7599
#
# Epoch 00250: val_loss improved from 0.46815 to 0.46776, saving model to known_classifier_nn.h5
# Epoch 251/50000
#  - 114s - loss: 0.5015 - acc: 0.7326 - val_loss: 0.4665 - val_acc: 0.7560
#
# Epoch 00251: val_loss improved from 0.46776 to 0.46647, saving model to known_classifier_nn.h5
# Epoch 252/50000
#  - 111s - loss: 0.5018 - acc: 0.7334 - val_loss: 0.4694 - val_acc: 0.7560
#
# Epoch 00252: val_loss did not improve
# Epoch 253/50000
#  - 116s - loss: 0.5044 - acc: 0.7316 - val_loss: 0.4719 - val_acc: 0.7599
#
# Epoch 00253: val_loss did not improve
# Epoch 254/50000
#  - 110s - loss: 0.5020 - acc: 0.7304 - val_loss: 0.4803 - val_acc: 0.7495
#
# Epoch 00254: val_loss did not improve
# Epoch 255/50000
#  - 113s - loss: 0.5017 - acc: 0.7328 - val_loss: 0.4706 - val_acc: 0.7596
#
# Epoch 00255: val_loss did not improve
# Epoch 256/50000
#  - 111s - loss: 0.5012 - acc: 0.7318 - val_loss: 0.4726 - val_acc: 0.7538
#
# Epoch 00256: val_loss did not improve
# Epoch 257/50000
#  - 112s - loss: 0.5015 - acc: 0.7329 - val_loss: 0.4810 - val_acc: 0.7502
#
# Epoch 00257: val_loss did not improve
# Epoch 258/50000
#  - 113s - loss: 0.5023 - acc: 0.7320 - val_loss: 0.4688 - val_acc: 0.7565
#
# Epoch 00258: val_loss did not improve
# Epoch 259/50000
#  - 112s - loss: 0.5014 - acc: 0.7351 - val_loss: 0.4701 - val_acc: 0.7557
#
# Epoch 00259: val_loss did not improve
# Epoch 260/50000
#  - 114s - loss: 0.5018 - acc: 0.7328 - val_loss: 0.4684 - val_acc: 0.7576
#
# Epoch 00260: val_loss did not improve
# Epoch 261/50000
#  - 115s - loss: 0.5016 - acc: 0.7331 - val_loss: 0.4705 - val_acc: 0.7554
#
# Epoch 00261: val_loss did not improve
# Epoch 262/50000
#  - 122s - loss: 0.5034 - acc: 0.7320 - val_loss: 0.4778 - val_acc: 0.7579
#
# Epoch 00262: val_loss did not improve
# Epoch 263/50000
#  - 115s - loss: 0.5045 - acc: 0.7308 - val_loss: 0.4737 - val_acc: 0.7555
#
# Epoch 00263: val_loss did not improve
# Epoch 264/50000
#  - 110s - loss: 0.5059 - acc: 0.7308 - val_loss: 0.4717 - val_acc: 0.7556
#
# Epoch 00264: val_loss did not improve
# Epoch 265/50000
#  - 115s - loss: 0.5050 - acc: 0.7295 - val_loss: 0.4707 - val_acc: 0.7603
#
# Epoch 00265: val_loss did not improve
# Epoch 266/50000
#  - 110s - loss: 0.5066 - acc: 0.7292 - val_loss: 0.4714 - val_acc: 0.7601
#
# Epoch 00266: val_loss did not improve
# Epoch 267/50000
#  - 109s - loss: 0.5068 - acc: 0.7297 - val_loss: 0.4952 - val_acc: 0.7444
#
# Epoch 00267: val_loss did not improve
# Epoch 268/50000
#  - 115s - loss: 0.5026 - acc: 0.7333 - val_loss: 0.4675 - val_acc: 0.7563
#
# Epoch 00268: val_loss did not improve
# Epoch 269/50000
#  - 112s - loss: 0.5039 - acc: 0.7342 - val_loss: 0.4718 - val_acc: 0.7590
#
# Epoch 00269: val_loss did not improve
# Epoch 270/50000
#  - 112s - loss: 0.5040 - acc: 0.7323 - val_loss: 0.4670 - val_acc: 0.7585
#
# Epoch 00270: val_loss did not improve
# Epoch 271/50000
#  - 111s - loss: 0.5009 - acc: 0.7332 - val_loss: 0.4705 - val_acc: 0.7577
#
# Epoch 00271: val_loss did not improve
# Epoch 272/50000
#  - 111s - loss: 0.5017 - acc: 0.7333 - val_loss: 0.4675 - val_acc: 0.7592
#
# Epoch 00272: val_loss did not improve
# Epoch 273/50000
#  - 115s - loss: 0.5015 - acc: 0.7322 - val_loss: 0.4671 - val_acc: 0.7581
#
# Epoch 00273: val_loss did not improve
# Epoch 274/50000
#  - 114s - loss: 0.5000 - acc: 0.7344 - val_loss: 0.4709 - val_acc: 0.7582
#
# Epoch 00274: val_loss did not improve
# Epoch 275/50000
#  - 114s - loss: 0.5021 - acc: 0.7310 - val_loss: 0.4720 - val_acc: 0.7598
#
# Epoch 00275: val_loss did not improve
# Epoch 276/50000
#  - 111s - loss: 0.5048 - acc: 0.7296 - val_loss: 0.4710 - val_acc: 0.7594
#
# Epoch 00276: val_loss did not improve
# Epoch 277/50000
#  - 115s - loss: 0.5048 - acc: 0.7302 - val_loss: 0.4691 - val_acc: 0.7609
#
# Epoch 00277: val_loss did not improve
# Epoch 278/50000
#  - 112s - loss: 0.5051 - acc: 0.7313 - val_loss: 0.4709 - val_acc: 0.7562
#
# Epoch 00278: val_loss did not improve
# Epoch 279/50000
#  - 113s - loss: 0.5056 - acc: 0.7299 - val_loss: 0.4697 - val_acc: 0.7585
#
# Epoch 00279: val_loss did not improve
# Epoch 280/50000
#  - 115s - loss: 0.5047 - acc: 0.7298 - val_loss: 0.4696 - val_acc: 0.7585
#
# Epoch 00280: val_loss did not improve
# Epoch 281/50000
#  - 112s - loss: 0.5012 - acc: 0.7334 - val_loss: 0.4701 - val_acc: 0.7590
#
# Epoch 00281: val_loss did not improve
# Epoch 282/50000
#  - 111s - loss: 0.5013 - acc: 0.7342 - val_loss: 0.4690 - val_acc: 0.7599
# Epoch 00282: val_loss did not improve
# Epoch 283/50000
#  - 115s - loss: 0.5012 - acc: 0.7349 - val_loss: 0.4719 - val_acc: 0.7586
#
# Epoch 00283: val_loss did not improve
# Epoch 284/50000
#  - 114s - loss: 0.5049 - acc: 0.7289 - val_loss: 0.4793 - val_acc: 0.7571
#
# Epoch 00284: val_loss did not improve
# Epoch 285/50000
#  - 116s - loss: 0.5085 - acc: 0.7308 - val_loss: 0.4684 - val_acc: 0.7584
#
# Epoch 00285: val_loss did not improve
# Epoch 286/50000
#  - 114s - loss: 0.5053 - acc: 0.7318 - val_loss: 0.4674 - val_acc: 0.7597
#
# Epoch 00286: val_loss did not improve
# Epoch 287/50000
#  - 115s - loss: 0.5059 - acc: 0.7292 - val_loss: 0.4756 - val_acc: 0.7541
#
# Epoch 00287: val_loss did not improve
# Epoch 288/50000
#  - 111s - loss: 0.5099 - acc: 0.7271 - val_loss: 0.4741 - val_acc: 0.7569
#
# Epoch 00288: val_loss did not improve
# Epoch 289/50000
#  - 115s - loss: 0.5091 - acc: 0.7261 - val_loss: 0.4730 - val_acc: 0.7590
#
# Epoch 00289: val_loss did not improve
# Epoch 290/50000
#  - 116s - loss: 0.5057 - acc: 0.7315 - val_loss: 0.4701 - val_acc: 0.7574
#
# Epoch 00290: val_loss did not improve
# Epoch 291/50000
#  - 110s - loss: 0.5017 - acc: 0.7311 - val_loss: 0.4657 - val_acc: 0.7600
#
# Epoch 00291: val_loss improved from 0.46647 to 0.46570, saving model to known_classifier_nn.h5
# Epoch 292/50000
#  - 114s - loss: 0.5022 - acc: 0.7348 - val_loss: 0.4699 - val_acc: 0.7583
#
# Epoch 00292: val_loss did not improve
# Epoch 293/50000
#  - 112s - loss: 0.4997 - acc: 0.7355 - val_loss: 0.4687 - val_acc: 0.7562
#
# Epoch 00293: val_loss did not improve
# Epoch 294/50000
#  - 113s - loss: 0.5066 - acc: 0.7296 - val_loss: 0.4746 - val_acc: 0.7567
#
# Epoch 00294: val_loss did not improve
# Epoch 295/50000
#  - 113s - loss: 0.5083 - acc: 0.7280 - val_loss: 0.4804 - val_acc: 0.7491
#
# Epoch 00295: val_loss did not improve
# Epoch 296/50000
#  - 116s - loss: 0.5040 - acc: 0.7315 - val_loss: 0.4709 - val_acc: 0.7577
#
# Epoch 00296: val_loss did not improve
# Epoch 297/50000
#  - 111s - loss: 0.5057 - acc: 0.7305 - val_loss: 0.4691 - val_acc: 0.7572
#
# Epoch 00297: val_loss did not improve
# Epoch 298/50000
#  - 116s - loss: 0.5060 - acc: 0.7295 - val_loss: 0.4718 - val_acc: 0.7593
#
# Epoch 00298: val_loss did not improve
# Epoch 299/50000
#  - 112s - loss: 0.5054 - acc: 0.7305 - val_loss: 0.4711 - val_acc: 0.7591
#
# Epoch 00299: val_loss did not improve
# Epoch 300/50000
#  - 109s - loss: 0.5079 - acc: 0.7290 - val_loss: 0.4677 - val_acc: 0.7575
#
# Epoch 00300: val_loss did not improve
# Epoch 301/50000
#  - 113s - loss: 0.5018 - acc: 0.7325 - val_loss: 0.4724 - val_acc: 0.7577
#
# Epoch 00301: val_loss did not improve
# Epoch 302/50000
#  - 114s - loss: 0.5051 - acc: 0.7295 - val_loss: 0.4679 - val_acc: 0.7603
#
# Epoch 00302: val_loss did not improve
# Epoch 303/50000
#  - 114s - loss: 0.5002 - acc: 0.7341 - val_loss: 0.4722 - val_acc: 0.7553
#
# Epoch 00303: val_loss did not improve
# Epoch 304/50000
#  - 114s - loss: 0.5026 - acc: 0.7324 - val_loss: 0.4663 - val_acc: 0.7610
#
# Epoch 00304: val_loss did not improve
# Epoch 305/50000
#  - 117s - loss: 0.5034 - acc: 0.7323 - val_loss: 0.4697 - val_acc: 0.7599
#
# Epoch 00305: val_loss did not improve
# Epoch 306/50000
#  - 112s - loss: 0.5041 - acc: 0.7327 - val_loss: 0.4720 - val_acc: 0.7561
#
# Epoch 00306: val_loss did not improve
# Epoch 307/50000
#  - 112s - loss: 0.5021 - acc: 0.7345 - val_loss: 0.4695 - val_acc: 0.7581
#
# Epoch 00307: val_loss did not improve
# Epoch 308/50000
#  - 111s - loss: 0.5022 - acc: 0.7323 - val_loss: 0.4688 - val_acc: 0.7564
#
# Epoch 00308: val_loss did not improve
# Epoch 309/50000
#  - 114s - loss: 0.5011 - acc: 0.7342 - val_loss: 0.4708 - val_acc: 0.7569
#
# Epoch 00309: val_loss did not improve
# Epoch 310/50000
#  - 114s - loss: 0.5038 - acc: 0.7316 - val_loss: 0.4716 - val_acc: 0.7547
#
# Epoch 00310: val_loss did not improve
# Epoch 311/50000
#  - 114s - loss: 0.5018 - acc: 0.7319 - val_loss: 0.4674 - val_acc: 0.7565
#
# Epoch 00311: val_loss did not improve
# Epoch 312/50000
#  - 115s - loss: 0.5012 - acc: 0.7343 - val_loss: 0.4697 - val_acc: 0.7578
#
# Epoch 00312: val_loss did not improve
# Epoch 313/50000
#  - 115s - loss: 0.4993 - acc: 0.7352 - val_loss: 0.4641 - val_acc: 0.7611
#
# Epoch 00313: val_loss improved from 0.46570 to 0.46414, saving model to known_classifier_nn.h5
# Epoch 314/50000
#  - 114s - loss: 0.4999 - acc: 0.7348 - val_loss: 0.4653 - val_acc: 0.7596
#
# Epoch 00314: val_loss did not improve
# Epoch 315/50000
#  - 112s - loss: 0.4992 - acc: 0.7349 - val_loss: 0.4683 - val_acc: 0.7590
#
# Epoch 00315: val_loss did not improve
# Epoch 316/50000
#  - 116s - loss: 0.4995 - acc: 0.7349 - val_loss: 0.4664 - val_acc: 0.7601
#
# Epoch 00316: val_loss did not improve
# Epoch 317/50000
#  - 114s - loss: 0.5009 - acc: 0.7341 - val_loss: 0.4736 - val_acc: 0.7565
#
# Epoch 00317: val_loss did not improve
# Epoch 318/50000
#  - 114s - loss: 0.5036 - acc: 0.7314 - val_loss: 0.4729 - val_acc: 0.7547
#
# Epoch 00318: val_loss did not improve
# Epoch 319/50000
#  - 112s - loss: 0.5020 - acc: 0.7330 - val_loss: 0.4779 - val_acc: 0.7542
#
# Epoch 00319: val_loss did not improve
# Epoch 320/50000
#  - 118s - loss: 0.4977 - acc: 0.7342 - val_loss: 0.4684 - val_acc: 0.7565
#
# Epoch 00320: val_loss did not improve
# Epoch 321/50000
#  - 115s - loss: 0.4989 - acc: 0.7363 - val_loss: 0.4646 - val_acc: 0.7588
#
# Epoch 00321: val_loss did not improve
# Epoch 322/50000
#  - 112s - loss: 0.4995 - acc: 0.7355 - val_loss: 0.4672 - val_acc: 0.7580
#
# Epoch 00322: val_loss did not improve
# Epoch 323/50000
#  - 116s - loss: 0.4996 - acc: 0.7343 - val_loss: 0.4666 - val_acc: 0.7594
#
# Epoch 00323: val_loss did not improve
# Epoch 324/50000
#  - 117s - loss: 0.5024 - acc: 0.7329 - val_loss: 0.4681 - val_acc: 0.7566
#
# Epoch 00324: val_loss did not improve
# Epoch 325/50000
#  - 115s - loss: 0.5009 - acc: 0.7341 - val_loss: 0.4648 - val_acc: 0.7610
#
# Epoch 00325: val_loss did not improve
# Epoch 326/50000
#  - 112s - loss: 0.4999 - acc: 0.7351 - val_loss: 0.4689 - val_acc: 0.7601
#
# Epoch 00326: val_loss did not improve
# Epoch 327/50000
#  - 111s - loss: 0.4986 - acc: 0.7350 - val_loss: 0.4666 - val_acc: 0.7594
#
# Epoch 00327: val_loss did not improve
# Epoch 328/50000
#  - 115s - loss: 0.4982 - acc: 0.7347 - val_loss: 0.4646 - val_acc: 0.7597
#
# Epoch 00328: val_loss did not improve
# Epoch 329/50000
#  - 114s - loss: 0.5025 - acc: 0.7333 - val_loss: 0.4736 - val_acc: 0.7582
#
# Epoch 00329: val_loss did not improve
# Epoch 330/50000
#  - 114s - loss: 0.5058 - acc: 0.7311 - val_loss: 0.4708 - val_acc: 0.7565
#
# Epoch 00330: val_loss did not improve
# Epoch 331/50000
#  - 114s - loss: 0.5040 - acc: 0.7324 - val_loss: 0.4659 - val_acc: 0.7580
#
# Epoch 00331: val_loss did not improve
# Epoch 332/50000
#  - 112s - loss: 0.5010 - acc: 0.7341 - val_loss: 0.4662 - val_acc: 0.7598
#
# Epoch 00332: val_loss did not improve
# Epoch 333/50000
#  - 117s - loss: 0.4969 - acc: 0.7355 - val_loss: 0.4644 - val_acc: 0.7610
#
# Epoch 00333: val_loss did not improve
# Epoch 334/50000
#  - 114s - loss: 0.5001 - acc: 0.7347 - val_loss: 0.4668 - val_acc: 0.7597
#
# Epoch 00334: val_loss did not improve
# Epoch 335/50000
# ...
#
# Epoch 00629: val_loss did not improve
# Epoch 630/50000
#  - 108s - loss: 0.5036 - acc: 0.7328 - val_loss: 0.4686 - val_acc: 0.7571
#
# Epoch 00630: val_loss did not improve
# Epoch 631/50000
#  - 105s - loss: 0.4961 - acc: 0.7366 - val_loss: 0.4635 - val_acc: 0.7578
#
# Epoch 00631: val_loss did not improve
# Epoch 632/50000
#  - 108s - loss: 0.4995 - acc: 0.7365 - val_loss: 0.4646 - val_acc: 0.7607
#
# Epoch 00632: val_loss did not improve
# Epoch 633/50000
#  - 112s - loss: 0.4968 - acc: 0.7364 - val_loss: 0.4646 - val_acc: 0.7606
#
# Epoch 00633: val_loss did not improve
# Epoch 634/50000
#  - 107s - loss: 0.4977 - acc: 0.7377 - val_loss: 0.4646 - val_acc: 0.7596
#
# Epoch 00634: val_loss did not improve
# Epoch 635/50000
#  - 109s - loss: 0.4961 - acc: 0.7386 - val_loss: 0.4623 - val_acc: 0.7619
#
# Epoch 00635: val_loss did not improve
# Epoch 636/50000
#  - 110s - loss: 0.5087 - acc: 0.7269 - val_loss: 0.4707 - val_acc: 0.7585
#
# Epoch 00636: val_loss did not improve
# Epoch 637/50000
#  - 111s - loss: 0.5116 - acc: 0.7259 - val_loss: 0.4734 - val_acc: 0.7460
#
# Epoch 00637: val_loss did not improve
# Epoch 638/50000
#  - 104s - loss: 0.5112 - acc: 0.7263 - val_loss: 0.4655 - val_acc: 0.7601
#
# Epoch 00638: val_loss did not improve
# Epoch 639/50000
#  - 106s - loss: 0.5016 - acc: 0.7327 - val_loss: 0.4628 - val_acc: 0.7577
#
# Epoch 00639: val_loss did not improve
# Epoch 640/50000
#  - 106s - loss: 0.4976 - acc: 0.7375 - val_loss: 0.4624 - val_acc: 0.7611
#
# Epoch 00640: val_loss did not improve
# Epoch 641/50000
#  - 109s - loss: 0.4965 - acc: 0.7380 - val_loss: 0.4616 - val_acc: 0.7608
#
# Epoch 00641: val_loss did not improve
# Epoch 642/50000
#  - 117s - loss: 0.4977 - acc: 0.7370 - val_loss: 0.4593 - val_acc: 0.7608
#
# Epoch 00642: val_loss improved from 0.45955 to 0.45929, saving model to known_classifier_nn.h5
# Epoch 643/50000
#  - 119s - loss: 0.4974 - acc: 0.7369 - val_loss: 0.4671 - val_acc: 0.7576
#
# Epoch 00643: val_loss did not improve
# Epoch 644/50000
#  - 132s - loss: 0.4968 - acc: 0.7377 - val_loss: 0.4649 - val_acc: 0.7605
#
# Epoch 00644: val_loss did not improve
# Epoch 645/50000
#  - 118s - loss: 0.4969 - acc: 0.7376 - val_loss: 0.4656 - val_acc: 0.7591
#
# Epoch 00645: val_loss did not improve
# Epoch 646/50000
#  - 111s - loss: 0.4994 - acc: 0.7338 - val_loss: 0.4641 - val_acc: 0.7586
#
# Epoch 00646: val_loss did not improve
# Epoch 647/50000
#  - 109s - loss: 0.4969 - acc: 0.7373 - val_loss: 0.4623 - val_acc: 0.7585
#
# Epoch 00647: val_loss did not improve
# Epoch 648/50000
#  - 108s - loss: 0.4969 - acc: 0.7367 - val_loss: 0.4601 - val_acc: 0.7610
#
# Epoch 00648: val_loss did not improve
# Epoch 649/50000
#  - 108s - loss: 0.5006 - acc: 0.7342 - val_loss: 0.4638 - val_acc: 0.7585
#
# Epoch 00649: val_loss did not improve
# Epoch 650/50000
#  - 107s - loss: 0.4981 - acc: 0.7373 - val_loss: 0.4654 - val_acc: 0.7580
#
# Epoch 00650: val_loss did not improve
# Epoch 651/50000
#  - 109s - loss: 0.5000 - acc: 0.7358 - val_loss: 0.4628 - val_acc: 0.7587
#
# Epoch 00651: val_loss did not improve
# Epoch 652/50000
#  - 107s - loss: 0.4973 - acc: 0.7377 - val_loss: 0.4673 - val_acc: 0.7563
#
# Epoch 00652: val_loss did not improve
# Epoch 653/50000
#  - 106s - loss: 0.4969 - acc: 0.7360 - val_loss: 0.4620 - val_acc: 0.7618
#
# Epoch 00653: val_loss did not improve
# Epoch 654/50000
#  - 109s - loss: 0.4957 - acc: 0.7381 - val_loss: 0.4658 - val_acc: 0.7581
#
# Epoch 00654: val_loss did not improve
# Epoch 655/50000
#  - 110s - loss: 0.5028 - acc: 0.7321 - val_loss: 0.4668 - val_acc: 0.7576
#
# Epoch 00655: val_loss did not improve
# Epoch 656/50000
#  - 110s - loss: 0.5094 - acc: 0.7272 - val_loss: 0.4695 - val_acc: 0.7556
#
# Epoch 00656: val_loss did not improve
# Epoch 657/50000
#  - 109s - loss: 0.5081 - acc: 0.7286 - val_loss: 0.4706 - val_acc: 0.7578
#
# Epoch 00657: val_loss did not improve
# Epoch 658/50000
#  - 114s - loss: 0.5079 - acc: 0.7275 - val_loss: 0.4665 - val_acc: 0.7608
#
# Epoch 00659: val_loss did not improve
# Epoch 660/50000
#  - 113s - loss: 0.5068 - acc: 0.7275 - val_loss: 0.4715 - val_acc: 0.7592
#
# Epoch 00660: val_loss did not improve
# Epoch 661/50000
#  - 117s - loss: 0.5059 - acc: 0.7300 - val_loss: 0.4629 - val_acc: 0.7574
#
# Epoch 00661: val_loss did not improve
# Epoch 662/50000
#  - 108s - loss: 0.5039 - acc: 0.7283 - val_loss: 0.4808 - val_acc: 0.7451
#
# Epoch 00662: val_loss did not improve
# Epoch 663/50000
#  - 107s - loss: 0.5112 - acc: 0.7245 - val_loss: 0.4789 - val_acc: 0.7417
#
# Epoch 00663: val_loss did not improve
# Epoch 664/50000
#  - 109s - loss: 0.5029 - acc: 0.7303 - val_loss: 0.4598 - val_acc: 0.7627
#
# Epoch 00664: val_loss did not improve
# Epoch 665/50000
#  - 108s - loss: 0.5069 - acc: 0.7299 - val_loss: 0.4771 - val_acc: 0.7565
#
# Epoch 00665: val_loss did not improve
# Epoch 666/50000
#  - 106s - loss: 0.5024 - acc: 0.7337 - val_loss: 0.4657 - val_acc: 0.7589
#
# Epoch 00666: val_loss did not improve
# Epoch 667/50000
#  - 107s - loss: 0.5008 - acc: 0.7350 - val_loss: 0.4652 - val_acc: 0.7597
#
# Epoch 00667: val_loss did not improve
# Epoch 668/50000
#  - 105s - loss: 0.4960 - acc: 0.7369 - val_loss: 0.4690 - val_acc: 0.7541
#
# Epoch 00668: val_loss did not improve
# Epoch 669/50000
#  - 110s - loss: 0.4975 - acc: 0.7352 - val_loss: 0.4645 - val_acc: 0.7590
#
# Epoch 00669: val_loss did not improve
# Epoch 670/50000
#  - 105s - loss: 0.5053 - acc: 0.7305 - val_loss: 0.4663 - val_acc: 0.7596
#
# Epoch 00670: val_loss did not improve
# Epoch 671/50000
#  - 107s - loss: 0.4999 - acc: 0.7362 - val_loss: 0.4626 - val_acc: 0.7602
#
# Epoch 00671: val_loss did not improve
# Epoch 672/50000
#  - 106s - loss: 0.5104 - acc: 0.7264 - val_loss: 0.4807 - val_acc: 0.7434
#
# Epoch 00672: val_loss did not improve
# Epoch 673/50000
#  - 106s - loss: 0.5123 - acc: 0.7250 - val_loss: 0.4730 - val_acc: 0.7564
#
# Epoch 00673: val_loss did not improve
# Epoch 674/50000
#  - 110s - loss: 0.5060 - acc: 0.7293 - val_loss: 0.4731 - val_acc: 0.7597
#
# Epoch 00674: val_loss did not improve
# Epoch 675/50000
#  - 111s - loss: 0.4982 - acc: 0.7368 - val_loss: 0.4652 - val_acc: 0.7576
#
# Epoch 00675: val_loss did not improve
# Epoch 676/50000
#  - 109s - loss: 0.5028 - acc: 0.7327 - val_loss: 0.4659 - val_acc: 0.7576
#
# Epoch 00676: val_loss did not improve
# Epoch 677/50000
#  - 106s - loss: 0.5063 - acc: 0.7300 - val_loss: 0.4664 - val_acc: 0.7559
#
# Epoch 00677: val_loss did not improve
# Epoch 678/50000
#  - 107s - loss: 0.5071 - acc: 0.7303 - val_loss: 0.4645 - val_acc: 0.7592
#
# Epoch 00678: val_loss did not improve
# Epoch 679/50000
#  - 108s - loss: 0.4963 - acc: 0.7359 - val_loss: 0.4647 - val_acc: 0.7601
#
# Epoch 00679: val_loss did not improve
# Epoch 680/50000
#  - 105s - loss: 0.4978 - acc: 0.7360 - val_loss: 0.4761 - val_acc: 0.7505
#
# Epoch 00680: val_loss did not improve
# Epoch 681/50000
#  - 108s - loss: 0.4981 - acc: 0.7359 - val_loss: 0.4826 - val_acc: 0.7441
#
# Epoch 00681: val_loss did not improve
# Epoch 682/50000
#  - 106s - loss: 0.5074 - acc: 0.7272 - val_loss: 0.4794 - val_acc: 0.7444
#
# Epoch 00682: val_loss did not improve
# Epoch 683/50000
#  - 109s - loss: 0.5091 - acc: 0.7259 - val_loss: 0.4730 - val_acc: 0.7570
#
# Epoch 00683: val_loss did not improve
# Epoch 684/50000
#  - 108s - loss: 0.5088 - acc: 0.7287 - val_loss: 0.4722 - val_acc: 0.7581
#
# Epoch 00684: val_loss did not improve
# Epoch 685/50000
#  - 105s - loss: 0.5040 - acc: 0.7305 - val_loss: 0.4674 - val_acc: 0.7603
#
# Epoch 00685: val_loss did not improve
# Epoch 686/50000
#  - 110s - loss: 0.5052 - acc: 0.7308 - val_loss: 0.4626 - val_acc: 0.7592
#
# Epoch 00686: val_loss did not improve
# Epoch 687/50000
#  - 112s - loss: 0.4980 - acc: 0.7362 - val_loss: 0.4627 - val_acc: 0.7578
#
# Epoch 00687: val_loss did not improve
# Epoch 688/50000
#  - 105s - loss: 0.4993 - acc: 0.7373 - val_loss: 0.4620 - val_acc: 0.7597
#
# Epoch 00688: val_loss did not improve
# Epoch 689/50000
#  - 107s - loss: 0.5044 - acc: 0.7318 - val_loss: 0.4788 - val_acc: 0.7581
#
# Epoch 00689: val_loss did not improve
# Epoch 690/50000
#  - 109s - loss: 0.5090 - acc: 0.7255 - val_loss: 0.4685 - val_acc: 0.7589
#
# Epoch 00690: val_loss did not improve
# Epoch 691/50000
#  - 109s - loss: 0.5051 - acc: 0.7314 - val_loss: 0.4657 - val_acc: 0.7581
#
# Epoch 00691: val_loss did not improve
# Epoch 692/50000
#  - 108s - loss: 0.4960 - acc: 0.7375 - val_loss: 0.4666 - val_acc: 0.7581
#
# Epoch 00692: val_loss did not improve
# Epoch 693/50000
#  - 106s - loss: 0.4990 - acc: 0.7372 - val_loss: 0.4684 - val_acc: 0.7559
#
# Epoch 00693: val_loss did not improve
# Epoch 694/50000
#  - 105s - loss: 0.5001 - acc: 0.7352 - val_loss: 0.4660 - val_acc: 0.7585
#
# Epoch 00694: val_loss did not improve
# Epoch 695/50000
#  - 106s - loss: 0.4985 - acc: 0.7359 - val_loss: 0.4643 - val_acc: 0.7591
#
# Epoch 00695: val_loss did not improve
# Epoch 696/50000
#  - 106s - loss: 0.4976 - acc: 0.7373 - val_loss: 0.4622 - val_acc: 0.7578
#
# Epoch 00696: val_loss did not improve
# Epoch 697/50000
#  - 109s - loss: 0.4964 - acc: 0.7378 - val_loss: 0.4626 - val_acc: 0.7597
#
# Epoch 00697: val_loss did not improve
# Epoch 698/50000
#  - 107s - loss: 0.4959 - acc: 0.7366 - val_loss: 0.4625 - val_acc: 0.7649
#
# Epoch 00698: val_loss did not improve
# Epoch 699/50000
#  - 105s - loss: 0.4983 - acc: 0.7360 - val_loss: 0.4659 - val_acc: 0.7626
#
# Epoch 00699: val_loss did not improve
# Epoch 700/50000
#  - 110s - loss: 0.4997 - acc: 0.7354 - val_loss: 0.4810 - val_acc: 0.7485
#
# Epoch 00700: val_loss did not improve
# Epoch 701/50000
#  - 105s - loss: 0.5034 - acc: 0.7357 - val_loss: 0.4640 - val_acc: 0.7599
#
# Epoch 00701: val_loss did not improve
# Epoch 702/50000
#  - 106s - loss: 0.5018 - acc: 0.7348 - val_loss: 0.4607 - val_acc: 0.7606
#
# Epoch 00702: val_loss did not improve
# Epoch 703/50000
#  - 109s - loss: 0.5009 - acc: 0.7344 - val_loss: 0.4635 - val_acc: 0.7606
#
# Epoch 00703: val_loss did not improve
# Epoch 704/50000
#  - 115s - loss: 0.5032 - acc: 0.7350 - val_loss: 0.4780 - val_acc: 0.7492
#
# Epoch 00704: val_loss did not improve
# Epoch 705/50000
#  - 108s - loss: 0.5117 - acc: 0.7277 - val_loss: 0.4684 - val_acc: 0.7585
#
# Epoch 00705: val_loss did not improve
# Epoch 706/50000
#  - 125s - loss: 0.5062 - acc: 0.7297 - val_loss: 0.4681 - val_acc: 0.7595
#
# Epoch 00706: val_loss did not improve
# Epoch 707/50000
#  - 121s - loss: 0.5079 - acc: 0.7272 - val_loss: 0.4850 - val_acc: 0.7452
#
# Epoch 00707: val_loss did not improve
# Epoch 708/50000
#  - 130s - loss: 0.5005 - acc: 0.7349 - val_loss: 0.4597 - val_acc: 0.7556
#
# Epoch 00708: val_loss did not improve
# Epoch 709/50000
#  - 121s - loss: 0.4972 - acc: 0.7377 - val_loss: 0.4626 - val_acc: 0.7599
#
# Epoch 00709: val_loss did not improve
# Epoch 710/50000
#  - 118s - loss: 0.5031 - acc: 0.7323 - val_loss: 0.4678 - val_acc: 0.7590
#
# Epoch 00710: val_loss did not improve
# Epoch 711/50000
#  - 125s - loss: 0.4982 - acc: 0.7365 - val_loss: 0.4657 - val_acc: 0.7601
#
# Epoch 00711: val_loss did not improve
# Epoch 712/50000
#  - 119s - loss: 0.5005 - acc: 0.7358 - val_loss: 0.4622 - val_acc: 0.7588
#
# Epoch 00712: val_loss did not improve
# Epoch 713/50000
#  - 117s - loss: 0.4968 - acc: 0.7378 - val_loss: 0.4644 - val_acc: 0.7572
#
# Epoch 00713: val_loss did not improve
# Epoch 714/50000
#  - 121s - loss: 0.4993 - acc: 0.7365 - val_loss: 0.4642 - val_acc: 0.7583
#
# Epoch 00714: val_loss did not improve
# Epoch 715/50000
#  - 125s - loss: 0.4995 - acc: 0.7350 - val_loss: 0.4642 - val_acc: 0.7576
#
# Epoch 00715: val_loss did not improve
# Epoch 716/50000
#  - 121s - loss: 0.5003 - acc: 0.7348 - val_loss: 0.4726 - val_acc: 0.7501
#
# Epoch 00716: val_loss did not improve
# Epoch 717/50000
#  - 113s - loss: 0.5046 - acc: 0.7286 - val_loss: 0.4905 - val_acc: 0.7228
#
# Epoch 00717: val_loss did not improve
# Epoch 718/50000
#  - 116s - loss: 0.5061 - acc: 0.7292 - val_loss: 0.4658 - val_acc: 0.7590
#
# Epoch 00718: val_loss did not improve
# Epoch 719/50000
#  - 119s - loss: 0.5098 - acc: 0.7251 - val_loss: 0.4737 - val_acc: 0.7565
#
# Epoch 00719: val_loss did not improve
# Epoch 720/50000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-112-00ca486bce8c> in <module>()
#      23
#      24 nn_model.fit(x_train, y_train, epochs=50000, batch_size=16, verbose=2,
# ---> 25              class_weight=class_weights, shuffle=True, validation_split=0.2, callbacks=[save_checkpoint, early_stop])
#
# ~\AppData\Local\conda\conda\envs\py36\lib\site-packages\keras\models.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#     961                               initial_epoch=initial_epoch,
#     962                               steps_per_epoch=steps_per_epoch,
# --> 963                               validation_steps=validation_steps)
#     964
#     965     def evaluate(self, x=None, y=None,
#
# ~\AppData\Local\conda\conda\envs\py36\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1703                               initial_epoch=initial_epoch,
#    1704                               steps_per_epoch=steps_per_epoch,
# -> 1705                               validation_steps=validation_steps)
#    1706
#    1707     def evaluate(self, x=None, y=None,
#
# ~\AppData\Local\conda\conda\envs\py36\lib\site-packages\keras\engine\training.py in _fit_loop(self, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#    1233                         ins_batch[i] = ins_batch[i].toarray()
#    1234
# -> 1235                     outs = f(ins_batch)
#    1236                     if not isinstance(outs, list):
#    1237                         outs = [outs]
#
# ~\AppData\Local\conda\conda\envs\py36\lib\site-packages\keras\backend\tensorflow_backend.py in __call__(self, inputs)
#    2476         session = get_session()
#    2477         updated = session.run(fetches=fetches, feed_dict=feed_dict,
# -> 2478                               **self.session_kwargs)
#    2479         return updated[:len(self.outputs)]
#    2480
#
# ~\AppData\Local\conda\conda\envs\py36\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     787     try:
#     788       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 789                          run_metadata_ptr)
#     790       if run_metadata:
#     791         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~\AppData\Local\conda\conda\envs\py36\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     995     if final_fetches or final_targets:
#     996       results = self._do_run(handle, final_targets, final_fetches,
# --> 997                              feed_dict_string, options, run_metadata)
#     998     else:
#     999       results = []
#
# ~\AppData\Local\conda\conda\envs\py36\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1130     if handle is None:
#    1131       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1132                            target_list, options, run_metadata)
#    1133     else:
#    1134       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# ~\AppData\Local\conda\conda\envs\py36\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1137   def _do_call(self, fn, *args):
#    1138     try:
# -> 1139       return fn(*args)
#    1140     except errors.OpError as e:
#    1141       message = compat.as_text(e.message)
#
# ~\AppData\Local\conda\conda\envs\py36\lib\site-packages\tensorflow\python\client\session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1119         return tf_session.TF_Run(session, options,
#    1120                                  feed_dict, fetch_list, target_list,
# -> 1121                                  status, run_metadata)
#    1122
#    1123     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %% [markdown]
# Neural Network Model Predictions

# %%
nn_preds = nn_model.predict(x_test)
nn_preds = np.array([1 if x > 0.5 else 0 for x in nn_preds]).astype('int64')

# %%
print(classification_report(y_test, nn_preds))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.73      0.67      0.70      8980
#           1       0.69      0.75      0.72      9020
#
# avg / total       0.71      0.71      0.71     18000

# %% [markdown]
# ### Accuracy scores for all 4 models

# %%
y_test = np.array(y_test)

print('Logistic Regression Model F1 Score and AUC: %f, %f, %f' % (accuracy_score(y_test, log_reg_preds), f1_score(y_test, log_reg_preds), roc_auc_score(y_test, log_reg_preds)))
print('Random Forest Model F1 Score and AUC: %f, %f, %f' % (accuracy_score(y_test, rf_preds), f1_score(y_test, rf_preds), roc_auc_score(y_test, rf_preds)))
print('XGBoost Model F1 Score and AUC: %f, %f, %f' % (accuracy_score(y_test, xgb_preds), f1_score(y_test, xgb_preds), roc_auc_score(y_test, xgb_preds)))
print('Neural Network Model F1 Score and AUC: %f, %f, %f' % (accuracy_score(y_test, nn_preds), f1_score(y_test, nn_preds), roc_auc_score(y_test, nn_preds)))
# Out:
# Logistic Regression Model F1 Score and AUC: 0.594167, 0.558637, 0.594348
# Random Forest Model F1 Score and AUC: 0.895389, 0.898430, 0.895327
# XGBoost Model F1 Score and AUC: 0.797222, 0.777385, 0.797424
# Neural Network Model F1 Score and AUC: 0.708278, 0.719932, 0.708189

# %% [markdown]
# ### Predicting on test set using best model

# %% [markdown]
# Loading submission dataset and filter to 57 features

# %%
submission_data = pd.read_csv('data/hackathon_IoT_validation_set_based_on_01mar2017_ANONYMIZED.csv')
submission_data_filtered = submission_data.filter(items=trimmed_feats_list, axis='columns')

# %% [markdown]
# Training KNN Model first to obtain distances

# %%
knn_x, knn_y = filtered_df.iloc[:, :-1].sample(200000), filtered_df.iloc[:, -1].sample(200000)
real_knn = KNeighborsClassifier(n_neighbors=10, weights='uniform', algorithm='auto', p=2, n_jobs=-1, leaf_size=20)
real_knn.fit(knn_x, knn_y)
sub_output = real_knn.kneighbors(submission_data_filtered, n_neighbors=10, return_distance=True)

# %% [markdown]
# Obtaining engineered features from submission dataset

# %%
sub_distance_df = pd.DataFrame([[distance for distance in row] for row in sub_output[0]])
sub_sd = sub_distance_df.std(axis=1, numeric_only=True)
sub_min = sub_distance_df.min(axis=1, numeric_only=True)
sub_mean = sub_distance_df.mean(axis=1, numeric_only=True)
sub_2_smallest_dist_df = pd.DataFrame(np.sort(sub_distance_df.values))
sub_2nd_smallest_dist_df = sub_2_smallest_dist_df.iloc[:, -2]
sub_smallest_dist_df = sub_2_smallest_dist_df.iloc[:, -1]

sub_distance_df['sd'] = sub_sd
sub_distance_df['sem'] = sub_distance_df.sem(axis=1, numeric_only=True)
sub_distance_df['var'] = sub_distance_df.var(axis=1, numeric_only=True)
sub_distance_df['skew'] = sub_distance_df.skew(axis=1, numeric_only=True)
sub_distance_df['kurt'] = sub_distance_df.kurt(axis=1, numeric_only=True)
sub_distance_df['mad'] = sub_distance_df.mad(axis=1)
sub_distance_df['shortest_dist_sd'] = sub_smallest_dist_df / sub_sd
sub_distance_df['shortest_dist_diff'] = (sub_mean - sub_min) / sub_sd
sub_distance_df['sd_diff_smallest2next'] = (sub_2nd_smallest_dist_df - sub_min) / sub_sd

# %%
sub_distance_df = sub_distance_df.replace([np.inf, -np.inf], np.nan)
sub_distance_df = sub_distance_df.replace(np.nan, 0)

# %%
bst.feature_names
# Out:
# ['f0', 'f1', 'f2', 'f3', 'f4', 'f5', 'f6', 'f7', 'f8']

# %%
known_sub_x = sub_distance_df.filter(items=training_cols, axis='columns')

# additional preprocessing for xgboost
sub_x = known_sub_x
sub_x.columns = bst.feature_names
sub_x = xgb.DMatrix(sub_x, label=np.zeros((sub_x.shape[0], 1)))

# known_preds = log_reg.predict(known_sub_x)
# known_preds = rf.predict(known_sub_x)
known_preds = bst.predict(sub_x)
# known_preds = nn_model.predict(known_sub_x)

# %%
known_preds
# Out:
# array([0.5200784 , 0.57257104, 0.5200784 , 0.5200784 , 0.5200784 ,
#        0.660773  , 0.660773  , 0.660773  , 0.65189266, 0.660773  ,
#        0.49470606, 0.56060416, 0.660773  , 0.65189266, 0.5200784 ,
#        0.49470606, 0.660773  , 0.49470606, 0.5200784 , 0.660773  ,
#        0.5200784 , 0.40510288, 0.660773  , 0.65189266, 0.49470606,
#        0.65189266, 0.65189266, 0.49470606, 0.57257104, 0.5200784 ,
#        0.65189266, 0.49470606, 0.57257104, 0.65189266, 0.5200784 ,
#        0.65189266, 0.660773  , 0.660773  , 0.5200784 , 0.65189266,
#        0.660773  , 0.65189266, 0.5200784 , 0.56060416, 0.660773  ,
#        0.5200784 , 0.65189266, 0.5200784 , 0.5200784 , 0.660773  ,
#        0.56060416, 0.56060416, 0.49470606, 0.65189266, 0.5200784 ,
#        0.65189266, 0.5200784 , 0.65189266, 0.5200784 , 0.5200784 ,
#        0.5200784 , 0.49470606, 0.5200784 , 0.6612021 , 0.5200784 ,
#        0.65189266, 0.5200784 , 0.6271014 , 0.5200784 , 0.660773  ,
#        0.57257104, 0.5200784 , 0.5200784 , 0.65189266, 0.660773  ,
#        0.660773  , 0.5200784 , 0.5200784 , 0.65189266, 0.65189266,
#        0.57257104, 0.56060416, 0.5200784 , 0.49470606, 0.5200784 ,
#        0.57257104, 0.660773  , 0.6271014 , 0.65189266, 0.660773  ,
#        0.5200784 , 0.65189266, 0.5200784 , 0.65189266, 0.5200784 ,
#        0.65189266, 0.5200784 , 0.57257104, 0.65189266, 0.660773  ,
#        0.5200784 , 0.65189266, 0.5200784 , 0.6271014 , 0.5200784 ,
#        0.57257104, 0.65189266, 0.660773  , 0.65189266, 0.660773  ,
#        0.6271014 , 0.49470606, 0.5200784 , 0.660773  , 0.65189266,
#        0.5200784 , 0.5200784 , 0.5200784 , 0.5200784 , 0.6951804 ,
#        0.5200784 , 0.65189266, 0.5200784 , 0.660773  , 0.660773  ,
#        0.49470606, 0.65189266, 0.660773  , 0.65189266, 0.65189266,
#        0.5200784 , 0.5450298 , 0.65189266, 0.57257104, 0.660773  ,
#        0.49470606, 0.5200784 , 0.660773  , 0.65189266, 0.65189266,
#        0.65189266, 0.65189266, 0.5200784 , 0.65189266, 0.5200784 ,
#        0.65189266, 0.49470606, 0.660773  , 0.65189266, 0.5200784 ,
#        0.5200784 , 0.48775038, 0.49470606, 0.5200784 , 0.65189266,
#        0.49470606, 0.5200784 , 0.65189266, 0.5200784 , 0.49470606,
#        0.5200784 , 0.57257104, 0.65189266, 0.5200784 , 0.5200784 ,
#        0.5200784 , 0.65189266, 0.5200784 , 0.56060416, 0.65189266,
#        0.56060416, 0.56060416, 0.65189266, 0.5200784 , 0.660773  ,
#        0.5200784 , 0.5200784 , 0.660773  , 0.5200784 , 0.48775038,
#        0.5200784 , 0.57257104, 0.660773  , 0.660773  , 0.57257104,
#        0.660773  , 0.65189266, 0.56060416, 0.5200784 , 0.5200784 ,
#        0.660773  , 0.56060416, 0.49470606, 0.65189266, 0.65189266,
#        0.5200784 , 0.56060416, 0.660773  , 0.660773  , 0.660773  ,
#        0.56060416, 0.660773  , 0.5200784 , 0.65189266, 0.660773  ,
#        0.5200784 , 0.660773  , 0.65189266, 0.65189266, 0.660773  ,
#        0.65189266, 0.49470606, 0.65189266, 0.5200784 , 0.5200784 ,
#        0.5200784 , 0.65189266, 0.660773  , 0.65189266, 0.660773  ,
#        0.660773  , 0.57257104, 0.5200784 , 0.5200784 , 0.56060416,
#        0.660773  , 0.5200784 , 0.5200784 , 0.49470606, 0.5200784 ,
#        0.65189266, 0.5200784 , 0.5200784 , 0.58374524, 0.5200784 ,
#        0.5200784 , 0.660773  , 0.660773  , 0.6271014 , 0.660773  ,
#        0.660773  , 0.660773  , 0.5200784 , 0.57257104, 0.5200784 ,
#        0.660773  , 0.65189266, 0.660773  , 0.660773  , 0.5200784 ,
#        0.660773  , 0.660773  , 0.660773  , 0.5200784 , 0.56060416,
#        0.48775038, 0.6951804 , 0.56060416, 0.5200784 , 0.49470606,
#        0.660773  , 0.49470606, 0.65189266, 0.65189266, 0.660773  ,
#        0.65189266, 0.65189266, 0.5200784 , 0.65189266, 0.65189266,
#        0.660773  , 0.57257104, 0.5200784 , 0.56060416, 0.660773  ,
#        0.56060416, 0.48775038, 0.660773  , 0.660773  , 0.660773  ,
#        0.5200784 , 0.660773  , 0.660773  , 0.48775038, 0.56060416,
#        0.660773  , 0.660773  , 0.5200784 , 0.660773  , 0.660773  ,
#        0.56060416, 0.65189266, 0.5200784 , 0.660773  , 0.660773  ,
#        0.5200784 , 0.65189266, 0.5200784 , 0.5200784 , 0.49470606,
#        0.58374524, 0.660773  , 0.65189266, 0.660773  , 0.5200784 ,
#        0.660773  , 0.5200784 , 0.56060416, 0.660773  , 0.5200784 ,
#        0.660773  , 0.58374524, 0.57257104, 0.49470606, 0.5200784 ,
#        0.5200784 , 0.49470606, 0.57257104, 0.660773  , 0.5200784 ,
#        0.660773  , 0.660773  , 0.49470606, 0.660773  , 0.65189266,
#        0.65189266, 0.660773  , 0.57257104, 0.57257104, 0.65189266,
#        0.56060416, 0.48775038, 0.65189266, 0.660773  , 0.65189266,
#        0.660773  , 0.660773  , 0.58374524, 0.65189266, 0.49470606,
#        0.48775038, 0.65189266, 0.660773  , 0.65189266, 0.5200784 ,
#        0.56060416, 0.660773  , 0.660773  , 0.5200784 , 0.6271014 ,
#        0.57257104, 0.57257104, 0.5200784 , 0.5200784 , 0.57257104,
#        0.65189266, 0.5200784 , 0.660773  , 0.56060416, 0.48775038,
#        0.660773  , 0.5200784 , 0.5200784 , 0.5200784 , 0.65189266,
#        0.660773  , 0.5200784 , 0.660773  , 0.5200784 , 0.48775038,
#        0.660773  , 0.65189266, 0.5200784 , 0.5200784 , 0.65189266,
#        0.660773  , 0.65189266, 0.65189266, 0.660773  , 0.5200784 ,
#        0.6271014 , 0.65189266, 0.5200784 , 0.5200784 , 0.57257104,
#        0.660773  , 0.660773  , 0.56060416, 0.5200784 , 0.5200784 ,
#        0.5200784 , 0.660773  , 0.5200784 , 0.5200784 , 0.58374524,
#        0.660773  , 0.58374524, 0.660773  , 0.57257104, 0.49470606,
#        0.5200784 , 0.58374524, 0.5200784 , 0.660773  , 0.56060416,
#        0.660773  , 0.660773  , 0.5200784 , 0.6271014 , 0.5200784 ,
#        0.5200784 , 0.65189266, 0.5200784 , 0.49470606, 0.5200784 ,
#        0.49470606, 0.5200784 , 0.6271014 , 0.5200784 , 0.57257104,
#        0.5200784 , 0.45989934, 0.48775038, 0.660773  , 0.660773  ,
#        0.5200784 , 0.5200784 , 0.65189266, 0.5200784 , 0.660773  ,
#        0.53095734, 0.660773  , 0.65189266, 0.5200784 , 0.65189266,
#        0.65189266, 0.65189266, 0.5200784 , 0.56060416, 0.56060416,
#        0.5200784 , 0.5200784 , 0.660773  , 0.65189266, 0.48775038,
#        0.65189266, 0.5200784 , 0.58374524, 0.56060416, 0.48775038,
#        0.5200784 , 0.660773  , 0.65189266, 0.65189266, 0.660773  ,
#        0.5200784 , 0.5200784 , 0.660773  , 0.6562932 , 0.5200784 ,
#        0.65189266, 0.65189266, 0.56060416, 0.5200784 , 0.5200784 ,
#        0.65189266, 0.65189266, 0.660773  , 0.48775038, 0.56060416,
#        0.5200784 , 0.65189266, 0.5200784 , 0.5200784 , 0.65189266,
#        0.660773  , 0.5200784 , 0.40510288, 0.40510288, 0.65189266,
#        0.660773  , 0.65189266, 0.5200784 , 0.660773  , 0.5200784 ,
#        0.65189266, 0.5200784 , 0.5200784 , 0.5200784 , 0.57257104,
#        0.65189266, 0.5200784 , 0.5200784 , 0.49470606, 0.660773  ,
#        0.56060416, 0.56060416, 0.57257104, 0.56060416, 0.660773  ,
#        0.5200784 , 0.5200784 , 0.660773  , 0.65189266, 0.5200784 ,
#        0.49470606, 0.65189266, 0.48775038, 0.48775038, 0.49470606,
#        0.49921417, 0.660773  , 0.65189266, 0.65189266, 0.660773  ,
#        0.5200784 , 0.5200784 , 0.660773  , 0.5200784 , 0.660773  ,
#        0.5200784 , 0.5200784 , 0.65189266, 0.5200784 , 0.660773  ,
#        0.5200784 , 0.48775038, 0.5200784 , 0.5200784 , 0.5200784 ,
#        0.660773  , 0.5200784 , 0.5200784 , 0.660773  , 0.65189266,
#        0.5200784 , 0.65189266, 0.5200784 , 0.660773  , 0.660773  ,
#        0.5200784 , 0.56060416, 0.5200784 , 0.660773  , 0.57257104,
#        0.5200784 , 0.6562932 , 0.48775038, 0.5200784 , 0.5200784 ,
#        0.5200784 , 0.6951804 , 0.660773  , 0.5200784 , 0.5200784 ,
#        0.6271014 , 0.5200784 , 0.65189266, 0.5200784 , 0.5200784 ,
#        0.660773  , 0.660773  , 0.65189266, 0.660773  , 0.660773  ,
#        0.5200784 , 0.5200784 , 0.5200784 , 0.5200784 , 0.660773  ,
#        0.660773  , 0.56060416, 0.42482817, 0.5200784 , 0.65189266,
#        0.5200784 , 0.5200784 , 0.57257104, 0.56060416, 0.5200784 ,
#        0.56060416, 0.5200784 , 0.65189266, 0.65189266, 0.65189266,
#        0.660773  , 0.5200784 , 0.660773  , 0.5200784 , 0.660773  ,
#        0.660773  , 0.49470606, 0.660773  , 0.5200784 , 0.57257104,
#        0.57257104, 0.5200784 , 0.5200784 , 0.65189266, 0.65189266,
#        0.660773  , 0.660773  , 0.5200784 , 0.6612021 , 0.40510288,
#        0.48775038, 0.5200784 , 0.5200784 , 0.5200784 , 0.660773  ,
#        0.49470606, 0.5200784 , 0.65189266, 0.660773  , 0.660773  ,
#        0.5200784 , 0.660773  , 0.65189266, 0.65189266, 0.5200784 ,
#        0.57257104, 0.5200784 , 0.660773  , 0.5200784 , 0.65189266,
#        0.5200784 , 0.49470606, 0.5200784 , 0.5200784 , 0.65189266,
#        0.65189266, 0.56060416, 0.660773  , 0.65189266, 0.660773  ,
#        0.65189266, 0.5200784 , 0.65189266, 0.56060416, 0.48775038,
#        0.5200784 , 0.58374524, 0.57257104, 0.5200784 , 0.660773  ,
#        0.65189266, 0.5200784 , 0.5200784 , 0.660773  , 0.5200784 ,
#        0.56060416, 0.660773  , 0.49470606, 0.65189266, 0.49470606,
#        0.5200784 , 0.660773  , 0.5200784 , 0.49470606, 0.660773  ,
#        0.65189266, 0.660773  , 0.48775038, 0.660773  , 0.5200784 ,
#        0.660773  , 0.65189266, 0.5200784 , 0.660773  , 0.660773  ,
#        0.65189266, 0.5200784 , 0.5200784 , 0.65189266, 0.65189266,
#        0.660773  , 0.660773  , 0.49470606, 0.660773  , 0.660773  ,
#        0.660773  , 0.49470606, 0.660773  , 0.49470606, 0.5200784 ,
#        0.65189266, 0.660773  , 0.660773  , 0.5200784 , 0.660773  ,
#        0.65189266, 0.49470606, 0.5200784 , 0.660773  , 0.5200784 ,
#        0.5200784 , 0.5200784 , 0.660773  , 0.57257104, 0.5200784 ,
#        0.5200784 , 0.660773  , 0.49470606, 0.65189266, 0.49470606,
#        0.5200784 , 0.5200784 , 0.660773  , 0.5200784 , 0.48775038,
#        0.5200784 , 0.5200784 , 0.65189266, 0.660773  , 0.5200784 ,
#        0.660773  , 0.49470606, 0.5200784 , 0.6951804 , 0.660773  ,
#        0.5200784 , 0.5200784 , 0.5200784 , 0.660773  , 0.57257104,
#        0.660773  , 0.57257104, 0.45989934, 0.660773  , 0.5200784 ,
#        0.65189266, 0.660773  , 0.5200784 , 0.65189266, 0.65189266,
#        0.56060416, 0.660773  , 0.5200784 , 0.660773  , 0.57257104,
#        0.65189266, 0.660773  , 0.6271014 , 0.5200784 , 0.65189266,
#        0.56060416, 0.65189266, 0.49470606, 0.660773  , 0.660773  ,
#        0.65189266, 0.5200784 , 0.56060416, 0.6271014 , 0.660773  ,
#        0.5200784 , 0.65189266, 0.57257104, 0.5200784 , 0.5200784 ,
#        0.5200784 , 0.5200784 , 0.49470606, 0.5200784 , 0.65189266,
#        0.65189266, 0.660773  , 0.5200784 , 0.660773  , 0.65189266,
#        0.660773  , 0.5200784 , 0.56060416, 0.660773  , 0.5200784 ,
#        0.5200784 , 0.5200784 , 0.5200784 , 0.48775038, 0.5200784 ,
#        0.660773  , 0.65189266, 0.65189266, 0.5200784 , 0.57257104,
#        0.5200784 , 0.65189266, 0.5200784 , 0.660773  , 0.5200784 ,
#        0.5200784 , 0.5200784 , 0.5200784 , 0.5200784 , 0.65189266,
#        0.49470606, 0.6271014 , 0.5200784 , 0.65189266, 0.65189266,
#        0.56060416, 0.49470606, 0.56060416, 0.57257104, 0.660773  ,
#        0.6271014 , 0.48775038, 0.65189266, 0.660773  , 0.5200784 ,
#        0.5200784 , 0.65189266, 0.660773  , 0.5200784 , 0.5200784 ,
#        0.49470606, 0.5200784 , 0.5200784 , 0.56060416, 0.660773  ,
#        0.48775038, 0.5200784 , 0.660773  , 0.65189266, 0.5200784 ,
#        0.40510288, 0.5200784 , 0.65189266, 0.5200784 , 0.39409897,
#        0.5200784 , 0.65189266, 0.65189266, 0.56060416, 0.49470606,
#        0.660773  , 0.5200784 , 0.65189266, 0.660773  , 0.660773  ,
#        0.5200784 , 0.49470606, 0.660773  , 0.65189266, 0.660773  ,
#        0.5200784 , 0.65189266, 0.5200784 , 0.5200784 , 0.5200784 ,
#        0.65189266, 0.48775038, 0.5450298 , 0.660773  , 0.6951804 ,
#        0.5200784 , 0.5200784 , 0.660773  , 0.5200784 , 0.5200784 ,
#        0.56060416, 0.65189266, 0.5200784 , 0.5200784 , 0.57257104,
#        0.660773  , 0.57257104, 0.49470606, 0.5200784 , 0.5200784 ,
#        0.660773  , 0.5200784 , 0.5200784 , 0.48775038, 0.660773  ,
#        0.5200784 , 0.660773  , 0.660773  , 0.49470606, 0.65189266,
#        0.660773  , 0.49470606, 0.5200784 , 0.65189266, 0.5200784 ,
#        0.49470606, 0.660773  , 0.49470606, 0.660773  , 0.49470606,
#        0.660773  , 0.660773  , 0.57257104, 0.660773  , 0.5200784 ,
#        0.65189266, 0.65189266, 0.5200784 , 0.660773  , 0.5200784 ,
#        0.5200784 , 0.5200784 , 0.5200784 , 0.660773  , 0.660773  ,
#        0.660773  , 0.57257104, 0.57257104, 0.5200784 , 0.6612021 ,
#        0.56060416, 0.5200784 , 0.660773  , 0.660773  , 0.660773  ,
#        0.65189266, 0.56060416, 0.56060416, 0.5200784 , 0.5200784 ,
#        0.5200784 , 0.57257104, 0.5200784 , 0.660773  , 0.660773  ,
#        0.660773  , 0.65189266, 0.65189266, 0.5200784 , 0.660773  ,
#        0.65189266, 0.56060416, 0.53095734, 0.57257104, 0.56060416,
#        0.660773  , 0.56060416, 0.660773  , 0.6951804 , 0.660773  ,
#        0.5200784 , 0.5200784 , 0.5200784 , 0.57257104, 0.660773  ,
#        0.6271014 , 0.5200784 , 0.56060416, 0.65189266, 0.65189266,
#        0.660773  , 0.65189266, 0.65189266, 0.65189266, 0.65189266,
#        0.5200784 , 0.5200784 , 0.65189266, 0.5200784 , 0.57257104,
#        0.5200784 , 0.56060416, 0.5200784 , 0.660773  , 0.5200784 ,
#        0.49470606, 0.48775038, 0.660773  , 0.660773  , 0.660773  ,
#        0.57257104, 0.5200784 , 0.5200784 , 0.49470606, 0.65189266,
#        0.5200784 , 0.49470606, 0.56060416, 0.660773  , 0.49470606,
#        0.660773  , 0.48775038, 0.660773  , 0.65189266, 0.660773  ,
#        0.65189266, 0.56060416, 0.56060416, 0.65189266, 0.5200784 ,
#        0.5200784 , 0.56060416, 0.65189266, 0.660773  , 0.65189266,
#        0.65189266, 0.5200784 , 0.57257104, 0.660773  , 0.660773  ],
#       dtype=float32)

# %%
known_preds_list = known_preds.tolist()


# log reg model output conversion
# No additional steps required

# rf model output conversion
# No additional steps required

# xgb model output conversion
known_preds_list = [1 if x > 0.5 else 0 for x in known_preds_list]

# nn model output conversion
# known_preds_list = [1 if x[0] > 0.5 else 0 for x in known_preds_list]


formatted_preds = pd.Series(['unknown' if row == 0 else None for row in known_preds_list])

# %%
model1_data_filtered = pd.concat([submission_data_filtered, formatted_preds], axis=1, )

# %%
model1_data_filtered.head()
# Out:
#       ttl_avg  domain_is_samsung  http_dom_host_alexaRank  http_has_location  \
# 0   58.518519                  0               2147483647                  0
# 1   59.375000                  1                      295                  1
# 2  129.902439                  0               2147483647                  0
# 3  255.000000                  0               2147483647                  0
# 4  255.000000                  0               2147483647                  0
#
#    packet_inter_arrivel_avg  packet_inter_arrivel_firstQ  \
# 0                  4.653678                     0.015224
# 1                  0.019548                     0.002045
# 2                  0.047890                     0.000078
# 3                140.821363                     0.499576
# 4                217.456576                     0.498901
#
#    packet_inter_arrivel_max  packet_inter_arrivel_A_avg  \
# 0                 37.375881                    7.562226
# 1                  0.060264                    0.034209
# 2                  0.269578                    0.087072
# 3               1828.971601                  140.821363
# 4               2208.373405                  217.456576
#
#    packet_inter_arrivel_stdev  packet_inter_arrivel_median  ...   \
# 0                    9.632666                     0.176993  ...
# 1                    0.021989                     0.014985  ...
# 2                    0.088786                     0.003968  ...
# 3                  470.474201                     0.500134  ...
# 4                  662.483985                     0.499896  ...
#
#    packet_size_A_min  ttl_thirdQ  B_is_dynamic_and_or_private_port  \
# 0                  0        64.0                                 0
# 1                  0        64.0                                 0
# 2                  0       225.0                                 0
# 3                  0       255.0                                 0
# 4                  0       255.0                                 0
#
#    packet_inter_arrivel_A_entropy  domain_is_dlink  \
# 0                        4.000000                0
# 1                        2.000000                0
# 2                        4.368523                0
# 3                        3.906891                0
# 4                        3.459432                0
#
#    packet_inter_arrivel_A_median  suffix_is_cloudfront.net  \
# 0                       0.430734                         0
# 1                       0.028752                         0
# 2                       0.018532                         0
# 3                       0.500134                         0
# 4                       0.499896                         0
#
#    http_cookie_values_entropy  http_inter_arrivel_stdev     0
# 0                           0                       0.0  None
# 1                           0                       0.0  None
# 2                           0                       0.0  None
# 3                           0                       0.0  None
# 4                           0                       0.0  None
#
# [5 rows x 57 columns]

# %%
model1_data_filtered.iloc[:, -1].value_counts()
# Out:
# unknown    100
# Name: 0, dtype: int64

# %%
joblib.dump(model1_data_filtered, 'unknown_classified_data.pkl', compress=9)
# Out:
# ['unknown_classified_data.pkl']
